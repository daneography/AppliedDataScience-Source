# %% [markdown]
# # Web Scraping: Part II - Scraping the Clemson Tigers Roster
#
# ```
# Prepared for CPSC4300/6300 Section 001 -- Applied Data Science
# Xizhou Feng
# Clemson University
# Fall 2020
# ```

# %% [markdown]
# # Overview
#
# In this notebook, we use the Blog by Brendan Martin, *Ultimate Guide to Web Scraping with Python Part 1: Requests and BeautifulSoup* (https://www.learndatasci.com/tutorials/ultimate-guide-web-scraping-w-python-requests-and-beautifulsoup/) as a template to create our notebook.

# %% [markdown]
# # Examine the Structure of the Clemson Tigers Roster
#
# Open the [ESPN's Clemson Tigers Roster webpage](https://www.espn.com/college-football/team/roster/_/id/228/clemson-tigers "ESPN's Clemson Tigers Roster") in your browser and examine its contents and structure using the "Developer Tools" of your browser.
#
# You may see a level 1 heading **Clemson Tigers Roste** followed by three tables captioned with "Offense", "Defense", and "Special Team".

# %% [markdown]
# # Download Web pages from Website
#
# As pointed out by Brendan in his blog, every time you load a web page,  you're making a request to a server and an incorrect code may submit thousands of requests a second to a website, which can cause damages to the owner. With this in mind, you want to be very careful with how we program scrapers to avoid crashing sites and causing damage.
#
# Normally, you should follow the following two guidelines:
#
# + Always check the website's policy (sites/robots.txt) about web crawling using robots.
# + Every time we scrape a website we want to attempt to make only one request per page.

# %% [markdown]
# ## Check The Sites's Robots Policy
#
# Open http://www.espn.com/robots.txt in your browser and skim the contents.
#
# ```
# # robots.txt for www.espn.com
#
# User-agent: *
# Disallow: */_/group/
# Disallow: */_/scoreboard/
# Disallow: */_/week/
# Disallow: */_/year/20
# Disallow: */admin/
# Disallow: */boxscore?/
# Disallow: */cat/
# ... more stuff ..
# ```
#
# A good news is that team roster is allowed (not among the list of disallowed pages) to scape at the ESPN site.

# %% [markdown]
# ## Make Web Requests
#
# We you interact with a website, you communicate the web servers using HTTP the protocol. The HTTP protocol specifies a set of methods such as `GET` and `POST` for you to talk with the webserver. The `requests` library is the de facto standard for making HTTP requests in Python. It abstracts the complexities of making requests behind a simple API. If you are not familar with the concepts around HTTP request, you may read a guide provided by Alex Ronquill (https://realpython.com/python-requests/).
#
# The code below shows how we make a request to get the Clemson Tigers Roste web page.

# %%
import requests
from requests.exceptions import HTTPError

url = 'https://www.espn.com/college-football/team/roster/_/id/228/clemson-tigers'

try: 
    response = requests.get(url)
except HTTPError as http_err:
    print('HTTP error occurred: {}'.format(http_err)) 
except Exception as err:
    print('Other error occurred: {}'.format(err))
else:
    print('Requesting {} is successful'.format(url))
# Out:
# Requesting https://www.espn.com/college-football/team/roster/_/id/228/clemson-tigers is successful

# %%
print(type(response))
print(response)
# Out:
# <class 'requests.models.Response'>
# <Response [200]>

# %% [markdown]
# You can list the attributes and methods of a response object using the `dir` function, the `__dict__` or `__attrs__` attributes of the object.

# %%
dir(response)
# Out:
# ['__attrs__',
#  '__bool__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__nonzero__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_content',
#  '_content_consumed',
#  '_next',
#  'apparent_encoding',
#  'close',
#  'connection',
#  'content',
#  'cookies',
#  'elapsed',
#  'encoding',
#  'headers',
#  'history',
#  'is_permanent_redirect',
#  'is_redirect',
#  'iter_content',
#  'iter_lines',
#  'json',
#  'links',
#  'next',
#  'ok',
#  'raise_for_status',
#  'raw',
#  'reason',
#  'request',
#  'status_code',
#  'text',
#  'url']

# %%
response.__dict__.keys()
# Out:
# dict_keys(['_content', '_content_consumed', '_next', 'status_code', 'headers', 'raw', 'url', 'encoding', 'history', 'reason', 'cookies', 'elapsed', 'request', 'connection'])

# %%
response.__attrs__
# Out:
# ['_content',
#  'status_code',
#  'headers',
#  'url',
#  'history',
#  'encoding',
#  'reason',
#  'cookies',
#  'elapsed',
#  'request']

# %%
response.content
# Out:
# b'\n        <!doctype html>\n        <html lang="en">\n            <head>\n                <meta charSet="utf-8" />\n\n                <!-- ESPNFITT | 926bd11e1492 | 4076 | 955e0eb0ecd8a0301101a5f70bd91686dd88caf8 | Tue, 01 Sep 2020 22:19:18 GMT -->\n                \n                <title data-react-helmet="true">Clemson Tigers Roster | ESPN</title>\n                <meta data-react-helmet="true" name="description" content="Visit ESPN to view the Clemson Tigers team roster for the current season"/><meta data-react-helmet="true" name="keywords" content="College Football, Football, Clemson Tigers, Roster"/><meta data-react-helmet="true" property="fb:app_id" content="116656161708917"/><meta data-react-helmet="true" property="og:site_name" content="ESPN"/><meta data-react-helmet="true" property="og:url" content="https://www.espn.com/college-football/team/roster/_/id/228/clemson-tigers"/><meta data-react-helmet="true" property="og:title" content="Clemson Tigers Roster | ESPN"/><meta data-react-helmet="true" property="og:description" content="Visit ESPN to view the Clemson Tigers team roster for the current season"/><meta data-react-helmet="true" property="og:image" content="https://a.espncdn.com/combiner/i?img=/i/teamlogos/ncaa/500/228.png"/><meta data-react-helmet="true" property="og:image:width" content="500"/><meta data-react-helmet="true" property="og:image:height" content="500"/><meta data-react-helmet="true" property="og:type" content="website"/><meta data-react-helmet="true" name="twitter:site" content="espn"/><meta data-react-helmet="true" name="twitter:url" content="https://www.espn.com/college-football/team/roster/_/id/228/clemson-tigers"/><meta data-react-helmet="true" name="twitter:title" content="Clemson Tigers Roster | ESPN"/><meta data-react-helmet="true" name="twitter:description" content="Visit ESPN to view the Clemson Tigers team roster for the current season"/><meta data-react-helmet="true" name="twitter:card" content="summary"/><meta data-react-helmet="true" name="twitter:image" content="https://a.espncdn.com/combiner/i?img=/i/teamlogos/ncaa/500/228.png"/><meta data-react-helmet="true" name="twitter:app:name:iphone" content="ESPN"/><meta data-react-helmet="true" name="twitter:app:id:iphone" content="317469184"/><meta data-react-helmet="true" name="twitter:app:name:googleplay" content="ESPN"/><meta data-react-helmet="true" name="twitter:app:id:googleplay" content="com.espn.score_center"/><meta data-react-helmet="true" name="title" content="Clemson Tigers Roster | ESPN"/><meta data-react-helmet="true" name="medium" content="website"/>\n                <meta name="viewport" content="initial-scale=1.0, maximum-scale=1.0, user-scalable=no" />\n                <meta http-equiv="x-ua-compatible" content="IE=edge" />\n                <meta property="og:locale" content="en_US" />\n\n                <link href="//cdn1.espn.net" rel="preconnect" />\n                <link href=\'https://tredir.espn.com\' rel=\'preconnect\' crossorigin />\n                <link href=\'https://cdn.registerdisney.go.com\' rel=\'preconnect\' crossorigin />\n                <link href=\'https://fan.api.espn.com\' rel=\'preconnect\' crossorigin />\n                <link href=\'https://cdn.espn.com\' rel=\'preconnect\' crossorigin />\n                <link href=\'https://a.espncdn.com\' rel=\'preconnect\' crossorigin />\n                <link href=\'https://site.web.api.espn.com\' rel=\'preconnect\' crossorigin />\n                <link rel="mask-icon" sizes="any" href="https://a.espncdn.com/prod/assets/icons/E.svg" color="#990000" />\n                <link rel="shortcut icon" href="https://a.espncdn.com/favicon.ico" />\n                <link rel="apple-touch-icon" href="https://a.espncdn.com/wireless/mw5/r1/images/bookmark-icons-v2/espn-icon-57x57.png" />\n                <link rel="apple-touch-icon-precomposed" href="https://a.espncdn.com/wireless/mw5/r1/images/bookmark-icons-v2/espn-icon-57x57.png" />\n                <link rel="apple-touch-i ...

# %% [markdown]
# ## Save the Webpage to a Local File
#
# To avoid repeatedly requesting a same page, we may save the web page to a local file.

# %%
def save_html(html, path):
    with open(path, 'wb') as f:
        f.write(html)
        
save_html(response.content, 'clemson_tiger_roster.html')

# %% [markdown]
# On linux, we can check the contenst of a text file using tools like `cat`, `head`, `tail`, `less`, `wc`, etc. You can run a linux command by puting a '!' character in frond of the command. For example.

# %%
# !ls -al *.html
# Out:
# -rw-r--r--@ 1 athena  staff  374122 Sep  1 18:19 clemson_tiger_roster.html

# %%
# !head -n 5 clemson_tiger_roster.html
# Out:
#         <!doctype html>
#         <html lang="en">
#             <head>
#                 <meta charSet="utf-8" />

# %% [markdown]
# ## Read HTML File

# %%
def read_html(path):
    with open(path, 'rb') as f:
        return f.read()
    
html = read_html('clemson_tiger_roster.html')

# %% [markdown]
# You can check the type and the contents of the html object by print both of them.

# %%
print(type(html))
print(html)
# Out:
# <class 'bytes'>
# b'\n        <!doctype html>\n        <html lang="en">\n            <head>\n                <meta charSet="utf-8" />\n\n                <!-- ESPNFITT | 926bd11e1492 | 4076 | 955e0eb0ecd8a0301101a5f70bd91686dd88caf8 | Tue, 01 Sep 2020 22:19:18 GMT -->\n                \n                <title data-react-helmet="true">Clemson Tigers Roster | ESPN</title>\n                <meta data-react-helmet="true" name="description" content="Visit ESPN to view the Clemson Tigers team roster for the current season"/><meta data-react-helmet="true" name="keywords" content="College Football, Football, Clemson Tigers, Roster"/><meta data-react-helmet="true" property="fb:app_id" content="116656161708917"/><meta data-react-helmet="true" property="og:site_name" content="ESPN"/><meta data-react-helmet="true" property="og:url" content="https://www.espn.com/college-football/team/roster/_/id/228/clemson-tigers"/><meta data-react-helmet="true" property="og:title" content="Clemson Tigers Roster | ESPN"/><meta data-react-helmet="true" property="og:description" content="Visit ESPN to view the Clemson Tigers team roster for the current season"/><meta data-react-helmet="true" property="og:image" content="https://a.espncdn.com/combiner/i?img=/i/teamlogos/ncaa/500/228.png"/><meta data-react-helmet="true" property="og:image:width" content="500"/><meta data-react-helmet="true" property="og:image:height" content="500"/><meta data-react-helmet="true" property="og:type" content="website"/><meta data-react-helmet="true" name="twitter:site" content="espn"/><meta data-react-helmet="true" name="twitter:url" content="https://www.espn.com/college-football/team/roster/_/id/228/clemson-tigers"/><meta data-react-helmet="true" name="twitter:title" content="Clemson Tigers Roster | ESPN"/><meta data-react-helmet="true" name="twitter:description" content="Visit ESPN to view the Clemson Tigers team roster for the current season"/><meta data-react-helmet="true" name="twitter:card" content="summary"/><meta data-react-helmet="true" name="twitter:image" content="https://a.espncdn.com/combiner/i?img=/i/teamlogos/ncaa/500/228.png"/><meta data-react-helmet="true" name="twitter:app:name:iphone" content="ESPN"/><meta data-react-helmet="true" name="twitter:app:id:iphone" content="317469184"/><meta data-react-helmet="true" name="twitter:app:name:googleplay" content="ESPN"/><meta data-react-helmet="true" name="twitter:app:id:googleplay" content="com.espn.score_center"/><meta data-react-helmet="true" name="title" content="Clemson Tigers Roster | ESPN"/><meta data-react-helmet="true" name="medium" content="website"/>\n                <meta name="viewport" content="initial-scale=1.0, maximum-scale=1.0, user-scalable=no" />\n                <meta http-equiv="x-ua-compatible" content="IE=edge" />\n                <meta property="og:locale" content="en_US" />\n\n                <link href="//cdn1.espn.net" rel="preconnect" />\n                <link href=\'https://tredir.espn.com\' rel=\'preconnect\' crossorigin />\n                <link href=\'https://cdn.registerdisney.go.com\' rel=\'preconnect\' crossorigin />\n                <link href=\'https://fan.api.espn.com\' rel=\'preconnect\' crossorigin />\n                <link href=\'https://cdn.espn.com\' rel=\'preconnect\' crossorigin />\n                <link href=\'https://a.espncdn.com\' rel=\'preconnect\' crossorigin />\n                <link href=\'https://site.web.api.espn.com\' rel=\'preconnect\' crossorigin />\n                <link rel="mask-icon" sizes="any" href="https://a.espncdn.com/prod/assets/icons/E.svg" color="#990000" />\n                <link rel="shortcut icon" href="https://a.espncdn.com/favicon.ico" />\n                <link rel="apple-touch-icon" href="https://a.espncdn.com/wireless/mw5/r1/images/bookmark-icons-v2/espn-icon-57x57.png" />\n                <link rel="apple-touch-icon-precomposed" href="https://a.espncdn.com/wireless/mw5/r1/images/bookmark-icons-v2/espn-icon-57x57.png" />\n                <link rel="apple-touch-i ...

# %% [markdown]
# It is easy to see that the html object has the same value and data type as the response.content object.

# %% [markdown]
# # Using Beautiful Soup to Extrac the Clemson Tigers Roster

# %% [markdown]
# ## Make the Soup

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(html, 'html.parser')

# %% [markdown]
# ## Find the Headings

# %%
soup.find_all('h1')
# Out:
# [<h1 class="ClubhouseHeader__Name ttu flex items-start n2"><span class="ClubhouseHeader__Rank clr-gray-05 pr2 n5">1</span><span class="flex flex-wrap"><span class="db pr3 nowrap fw-bold">Clemson</span><span class="db">Tigers</span></span></h1>,
#  <h1 class="headline headline__h1 dib">Clemson Tigers Roster</h1>]

# %%
h1 = soup.find('h1', string='Clemson Tigers Roster')
h1
# Out:
# <h1 class="headline headline__h1 dib">Clemson Tigers Roster</h1>

# %%
tables = soup.find_all('table')

# %%
type(tables)
# Out:
# bs4.element.ResultSet

# %%
t1 = tables[0]
for c in t1.children:
    print(c.name)
# Out:
# colgroup
# thead
# tbody

# %%
t1.parent.parent.parent.parent.parent
# Out:
# <div><div class="ResponsiveTable Offense"><div class="Table__Title">Offense</div><div class="flex"><div class="Table__ScrollerWrapper relative overflow-hidden"><div class="Table__Shadow--left" style="opacity:0"></div><div class="Table__Scroller"><table class="Table" style="border-collapse:collapse;border-spacing:0"><colgroup class="Table__Colgroup"><col class="Table__Column"/><col class="Table__Column"/><col class="Table__Column"/><col class="Table__Column"/><col class="Table__Column"/><col class="Table__Column"/><col class="Table__Column"/></colgroup><thead class="Table__header-group Table__THEAD"><tr class="Table__sub-header Table__TR Table__even"><th class="Table__TD--headshot Table__TH" title=""><span class="fw-medium w-100 dib Table__TD--headshot" style="min-width:40px" title=""></span></th><th class="Table__TH" title=""><span class="fw-medium w-100 dib" style="min-width:140px" title="">Name</span></th><th class="Table__TH" title=""><span class="fw-medium w-100 dib underline" title=""><a class="AnchorLink clr-gray-04" href="/college-football/team/roster/_/id/228/sort/position/dir/asc/clemson-tigers" tabindex="0">POS</a></span></th><th class="Table__TH" title=""><span class="fw-medium w-100 dib underline" style="min-width:50px" title=""><a class="AnchorLink clr-gray-04" href="/college-football/team/roster/_/id/228/sort/height/dir/asc/clemson-tigers" tabindex="0">HT</a></span></th><th class="Table__TH" title=""><span class="fw-medium w-100 dib underline" style="min-width:70px" title=""><a class="AnchorLink clr-gray-04" href="/college-football/team/roster/_/id/228/sort/weight/dir/asc/clemson-tigers" tabindex="0">WT</a></span></th><th class="Table__TH" title=""><span class="fw-medium w-100 dib underline" title=""><a class="AnchorLink clr-gray-04" href="/college-football/team/roster/_/id/228/sort/experience/dir/asc/clemson-tigers" tabindex="0">Class</a></span></th><th class="Table__TH" title=""><span class="fw-medium w-100 dib" title="">Birthplace</span></th></tr></thead><tbody class="Table__TBODY"><tr class="Table__TR Table__TR--lg Table__even" data-idx="0"><td class="Table__TD--headshot Table__TD"><div class="inline Table__TD--headshot" style="min-width:40px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4686096/hunter-helms" tabindex="0"><div class="headshot inline-block relative TableHeadshot roster-headshot headshot--sm athlete silo"><figure class="Image aspect-ratio--parent"><div class="RatioFrame aspect-ratio--1x1"></div><div class="Image__Wrapper aspect-ratio--child"><img alt="https://a.espncdn.com/i/headshots/college-football/players/full/4686096.png" class="" data-mptype="image" src="..." title="Hunter Helms"/></div></figure></div></a></div></td><td class="Table__TD"><div class="inline" style="min-width:140px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4686096/hunter-helms" tabindex="0">Hunter Helms</a><span class="pl2 n10">18</span></div></td><td class="Table__TD"><div class="inline">QB</div></td><td class="Table__TD"><div class="inline" style="min-width:50px">6' 2"</div></td><td class="Table__TD"><div class="inline" style="min-width:70px">210 lbs</div></td><td class="Table__TD"><div class="inline">FR</div></td><td class="Table__TD"><div class="inline">West Columbia, SC</div></td></tr><tr class="Table__TR Table__TR--lg Table__even" data-idx="1"><td class="Table__TD--headshot Table__TD"><div class="inline Table__TD--headshot" style="min-width:40px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4360310/trevor-lawrence" tabindex="0"><div class="headshot inline-block relative TableHeadshot roster-headshot headshot--sm athlete silo"><figure class="Image aspect-ratio--parent"><div class="RatioFrame aspect-ratio--1x1"></div><div class="Image__Wrapper aspect-ratio--child"><img alt="https://a.espncdn.com/i/headshots/college-football/players/full/4360310.png" class="" data-mptype="image" src="..." title="Trevor Lawrence"/></div></f ...

# %%
tb = t1.find("tbody")
for c in tb.children:
    print(c)
# Out:
# <tr class="Table__TR Table__TR--lg Table__even" data-idx="0"><td class="Table__TD--headshot Table__TD"><div class="inline Table__TD--headshot" style="min-width:40px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4686096/hunter-helms" tabindex="0"><div class="headshot inline-block relative TableHeadshot roster-headshot headshot--sm athlete silo"><figure class="Image aspect-ratio--parent"><div class="RatioFrame aspect-ratio--1x1"></div><div class="Image__Wrapper aspect-ratio--child"><img alt="https://a.espncdn.com/i/headshots/college-football/players/full/4686096.png" class="" data-mptype="image" src="..." title="Hunter Helms"/></div></figure></div></a></div></td><td class="Table__TD"><div class="inline" style="min-width:140px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4686096/hunter-helms" tabindex="0">Hunter Helms</a><span class="pl2 n10">18</span></div></td><td class="Table__TD"><div class="inline">QB</div></td><td class="Table__TD"><div class="inline" style="min-width:50px">6' 2"</div></td><td class="Table__TD"><div class="inline" style="min-width:70px">210 lbs</div></td><td class="Table__TD"><div class="inline">FR</div></td><td class="Table__TD"><div class="inline">West Columbia, SC</div></td></tr>
# <tr class="Table__TR Table__TR--lg Table__even" data-idx="1"><td class="Table__TD--headshot Table__TD"><div class="inline Table__TD--headshot" style="min-width:40px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4360310/trevor-lawrence" tabindex="0"><div class="headshot inline-block relative TableHeadshot roster-headshot headshot--sm athlete silo"><figure class="Image aspect-ratio--parent"><div class="RatioFrame aspect-ratio--1x1"></div><div class="Image__Wrapper aspect-ratio--child"><img alt="https://a.espncdn.com/i/headshots/college-football/players/full/4360310.png" class="" data-mptype="image" src="..." title="Trevor Lawrence"/></div></figure></div></a></div></td><td class="Table__TD"><div class="inline" style="min-width:140px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4360310/trevor-lawrence" tabindex="0">Trevor Lawrence</a><span class="pl2 n10">16</span></div></td><td class="Table__TD"><div class="inline">QB</div></td><td class="Table__TD"><div class="inline" style="min-width:50px">6' 6"</div></td><td class="Table__TD"><div class="inline" style="min-width:70px">220 lbs</div></td><td class="Table__TD"><div class="inline">JR</div></td><td class="Table__TD"><div class="inline">Cartersville, GA</div></td></tr>
# <tr class="Table__TR Table__TR--lg Table__even" data-idx="2"><td class="Table__TD--headshot Table__TD"><div class="inline Table__TD--headshot" style="min-width:40px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4249919/patrick-mcclure" tabindex="0"><div class="headshot inline-block relative TableHeadshot roster-headshot headshot--sm athlete silo"><figure class="Image aspect-ratio--parent"><div class="RatioFrame aspect-ratio--1x1"></div><div class="Image__Wrapper aspect-ratio--child"><img alt="https://a.espncdn.com/i/headshots/college-football/players/full/4249919.png" class="" data-mptype="image" src="..." title="Patrick McClure"/></div></figure></div></a></div></td><td class="Table__TD"><div class="inline" style="min-width:140px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4249919/patrick-mcclure" tabindex="0">Patrick McClure</a><span class="pl2 n10">15</span></div></td><td class="Table__TD"><div class="inline">QB</div></td><td class="Table__TD"><div class="inline" style="min-width:50px">6' 1"</div></td><td class="Table__TD"><div class="inline" style="min-width:70px">200 lbs</div></td><td class="Table__TD"><div class="inline">JR</div></td><td class="Table__TD"><div class="inline">Irmo, SC</div></td></tr>
# <tr class="Table__TR Table__TR--lg Table__even" data-idx="3"><td class="Table__TD--headshot Table__TD"><div class="inline Table__TD--headshot" style="min-width:40px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4426430/taisun-phommachanh" tabindex="0"><div class="headshot inline-block relative TableHeadshot roster-headshot headshot--sm athlete silo"><figure class="Image aspect-ratio--parent"><div class="RatioFrame aspect-ratio--1x1"></div><div class="Image__Wrapper aspect-ratio--child"><img alt="https://a.espncdn.com/i/headshots/college-football/players/full/4426430.png" class="" data-mptype="image" src="..." title="Taisun Phommachanh"/></div></figure></div></a></div></td><td class="Table__TD"><div class="inline" style="min-width:140px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4426430/taisun-phommachanh" tabindex="0">Taisun Phommachanh</a><span class="pl2 n10">7</span></div></td><td class="Table__TD"><div class="inline">QB</div></td><td class="Table__TD"><div class="inline" style="min-width:50px">6' 3"</div></td><td class="Table__TD"><div class="inline" style="min-width:70px">220 lbs</div></td><td class="Table__TD"><div class="inline">FR</div></td><td class="Table__TD"><div class="inline">Bridgeport, CT</div></td></tr>
# <tr class="Table__TR Table__TR--lg Table__even" data-idx="4"><td class="Table__TD--headshot Table__TD"><div class="inline Table__TD--headshot" style="min-width:40px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4429020/dj-uiagalelei" tabindex="0"><div class="headshot inline-block relative TableHeadshot roster-headshot headshot--sm athlete silo"><figure class="Image aspect-ratio--parent"><div class="RatioFrame aspect-ratio--1x1"></div><div class="Image__Wrapper aspect-ratio--child"><img alt="https://a.espncdn.com/i/headshots/college-football/players/full/4429020.png" class="" data-mptype="image" src="..." title="D.J. Uiagalelei"/></div></figure></div></a></div></td><td class="Table__TD"><div class="inline" style="min-width:140px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4429020/dj-uiagalelei" tabindex="0">D.J. Uiagalelei</a><span class="pl2 n10">5</span></div></td><td class="Table__TD"><div class="inline">QB</div></td><td class="Table__TD"><div class="inline" style="min-width:50px">6' 5"</div></td><td class="Table__TD"><div class="inline" style="min-width:70px">245 lbs</div></td><td class="Table__TD"><div class="inline">FR</div></td><td class="Table__TD"><div class="inline">Bellflower, CA</div></td></tr>
# <tr class="Table__TR Table__TR--lg Table__even" data-idx="5"><td class="Table__TD--headshot Table__TD"><div class="inline Table__TD--headshot" style="min-width:40px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4429002/demarkcus-bowman" tabindex="0"><div class="headshot inline-block relative TableHeadshot roster-headshot headshot--sm athlete silo"><figure class="Image aspect-ratio--parent"><div class="RatioFrame aspect-ratio--1x1"></div><div class="Image__Wrapper aspect-ratio--child"><img alt="https://a.espncdn.com/i/headshots/college-football/players/full/4429002.png" class="" data-mptype="image" src="..." title="Demarkcus Bowman"/></div></figure></div></a></div></td><td class="Table__TD"><div class="inline" style="min-width:140px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4429002/demarkcus-bowman" tabindex="0">Demarkcus Bowman</a><span class="pl2 n10">1</span></div></td><td class="Table__TD"><div class="inline">RB</div></td><td class="Table__TD"><div class="inline" style="min-width:50px">5' 10"</div></td><td class="Table__TD"><div class="inline" style="min-width:70px">190 lbs</div></td><td class="Table__TD"><div class="inline">FR</div></td><td class="Table__TD"><div class="inline">Lakeland, FL</div></td></tr>
# <tr class="Table__TR Table__TR--lg Table__even" data-idx="6"><td class="Table__TD--headshot Table__TD"><div class="inline Table__TD--headshot" style="min-width:40px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4360314/lyn-j-dixon" tabindex="0"><div class="headshot inline-block relative TableHeadshot roster-headshot headshot--sm athlete silo"><figure class="Image aspect-ratio--parent"><div class="RatioFrame aspect-ratio--1x1"></div><div class="Image__Wrapper aspect-ratio--child"><img alt="https://a.espncdn.com/i/headshots/college-football/players/full/4360314.png" class="" data-mptype="image" src="..." title="Lyn-J Dixon"/></div></figure></div></a></div></td><td class="Table__TD"><div class="inline" style="min-width:140px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4360314/lyn-j-dixon" tabindex="0">Lyn-J Dixon</a><span class="pl2 n10">23</span></div></td><td class="Table__TD"><div class="inline">RB</div></td><td class="Table__TD"><div class="inline" style="min-width:50px">5' 10"</div></td><td class="Table__TD"><div class="inline" style="min-width:70px">190 lbs</div></td><td class="Table__TD"><div class="inline">JR</div></td><td class="Table__TD"><div class="inline">Butler, GA</div></td></tr>
# <tr class="Table__TR Table__TR--lg Table__even" data-idx="7"><td class="Table__TD--headshot Table__TD"><div class="inline Table__TD--headshot" style="min-width:40px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4427111/michel-dukes" tabindex="0"><div class="headshot inline-block relative TableHeadshot roster-headshot headshot--sm athlete silo"><figure class="Image aspect-ratio--parent"><div class="RatioFrame aspect-ratio--1x1"></div><div class="Image__Wrapper aspect-ratio--child"><img alt="https://a.espncdn.com/i/headshots/college-football/players/full/4427111.png" class="" data-mptype="image" src="..." title="Michel Dukes"/></div></figure></div></a></div></td><td class="Table__TD"><div class="inline" style="min-width:140px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4427111/michel-dukes" tabindex="0">Michel Dukes</a><span class="pl2 n10">19</span></div></td><td class="Table__TD"><div class="inline">RB</div></td><td class="Table__TD"><div class="inline" style="min-width:50px">5' 10"</div></td><td class="Table__TD"><div class="inline" style="min-width:70px">195 lbs</div></td><td class="Table__TD"><div class="inline">SO</div></td><td class="Table__TD"><div class="inline">Charleston, SC</div></td></tr>
# <tr class="Table__TR Table__TR--lg Table__even" data-idx="8"><td class="Table__TD--headshot Table__TD"><div class="inline Table__TD--headshot" style="min-width:40px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4239996/travis-etienne" tabindex="0"><div class="headshot inline-block relative TableHeadshot roster-headshot headshot--sm athlete silo"><figure class="Image aspect-ratio--parent"><div class="RatioFrame aspect-ratio--1x1"></div><div class="Image__Wrapper aspect-ratio--child"><img alt="https://a.espncdn.com/i/headshots/college-football/players/full/4239996.png" class="" data-mptype="image" src="..." title="Travis Etienne"/></div></figure></div></a></div></td><td class="Table__TD"><div class="inline" style="min-width:140px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4239996/travis-etienne" tabindex="0">Travis Etienne</a><span class="pl2 n10">9</span></div></td><td class="Table__TD"><div class="inline">RB</div></td><td class="Table__TD"><div class="inline" style="min-width:50px">5' 10"</div></td><td class="Table__TD"><div class="inline" style="min-width:70px">210 lbs</div></td><td class="Table__TD"><div class="inline">SR</div></td><td class="Table__TD"><div class="inline">Jennings, LA</div></td></tr>
# <tr class="Table__TR Table__TR--lg Table__even" data-idx="9"><td class="Table__TD--headshot Table__TD"><div class="inline Table__TD--headshot" style="min-width:40px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4391365/ty-lucas" tabindex="0"><div class="headshot inline-block relative TableHeadshot roster-headshot headshot--sm athlete silo"><figure class="Image aspect-ratio--parent"><div class="RatioFrame aspect-ratio--1x1"></div><div class="Image__Wrapper aspect-ratio--child"><img alt="https://a.espncdn.com/i/headshots/college-football/players/full/4391365.png" class="" data-mptype="image" src="..." title="Ty Lucas"/></div></figure></div></a></div></td><td class="Table__TD"><div class="inline" style="min-width:140px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4391365/ty-lucas" tabindex="0">Ty Lucas</a><span class="pl2 n10">33</span></div></td><td class="Table__TD"><div class="inline">RB</div></td><td class="Table__TD"><div class="inline" style="min-width:50px">5' 7"</div></td><td class="Table__TD"><div class="inline" style="min-width:70px">205 lbs</div></td><td class="Table__TD"><div class="inline">SO</div></td><td class="Table__TD"><div class="inline">Columbus, GA</div></td></tr>
# <tr class="Table__TR Table__TR--lg Table__even" data-idx="10"><td class="Table__TD--headshot Table__TD"><div class="inline Table__TD--headshot" style="min-width:40px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4273963/sylvester-mayers" tabindex="0"><div class="headshot inline-block relative TableHeadshot roster-headshot headshot--sm athlete silo"><figure class="Image aspect-ratio--parent"><div class="RatioFrame aspect-ratio--1x1"></div><div class="Image__Wrapper aspect-ratio--child"><img alt="https://a.espncdn.com/i/headshots/college-football/players/full/4273963.png" class="" data-mptype="image" src="..." title="Sylvester Mayers"/></div></figure></div></a></div></td><td class="Table__TD"><div class="inline" style="min-width:140px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4273963/sylvester-mayers" tabindex="0">Sylvester Mayers</a><span class="pl2 n10">32</span></div></td><td class="Table__TD"><div class="inline">RB</div></td><td class="Table__TD"><div class="inline" style="min-width:50px">5' 6"</div></td><td class="Table__TD"><div class="inline" style="min-width:70px">150 lbs</div></td><td class="Table__TD"><div class="inline">JR</div></td><td class="Table__TD"><div class="inline">Richmond, VA</div></td></tr>
# <tr class="Table__TR Table__TR--lg Table__even" data-idx="11"><td class="Table__TD--headshot Table__TD"><div class="inline Table__TD--headshot" style="min-width:40px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4426409/chez-mellusi" tabindex="0"><div class="headshot inline-block relative TableHeadshot roster-headshot headshot--sm athlete silo"><figure class="Image aspect-ratio--parent"><div class="RatioFrame aspect-ratio--1x1"></div><div class="Image__Wrapper aspect-ratio--child"><img alt="https://a.espncdn.com/i/headshots/college-football/players/full/4426409.png" class="" data-mptype="image" src="..." title="Chez Mellusi"/></div></figure></div></a></div></td><td class="Table__TD"><div class="inline" style="min-width:140px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4426409/chez-mellusi" tabindex="0">Chez Mellusi</a><span class="pl2 n10">27</span></div></td><td class="Table__TD"><div class="inline">RB</div></td><td class="Table__TD"><div class="inline" style="min-width:50px">5' 11"</div></td><td class="Table__TD"><div class="inline" style="min-width:70px">200 lbs</div></td><td class="Table__TD"><div class="inline">SO</div></td><td class="Table__TD"><div class="inline">Naples, FL</div></td></tr>
# <tr class="Table__TR Table__TR--lg Table__even" data-idx="12"><td class="Table__TD--headshot Table__TD"><div class="inline Table__TD--headshot" style="min-width:40px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4686095/kobe-pace" tabindex="0"><div class="headshot inline-block relative TableHeadshot roster-headshot headshot--sm athlete silo"><figure class="Image aspect-ratio--parent"><div class="RatioFrame aspect-ratio--1x1"></div><div class="Image__Wrapper aspect-ratio--child"><img alt="https://a.espncdn.com/i/headshots/college-football/players/full/4686095.png" class="" data-mptype="image" src="..." title="Kobe Pace"/></div></figure></div></a></div></td><td class="Table__TD"><div class="inline" style="min-width:140px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4686095/kobe-pace" tabindex="0">Kobe Pace</a><span class="pl2 n10">14</span></div></td><td class="Table__TD"><div class="inline">RB</div></td><td class="Table__TD"><div class="inline" style="min-width:50px">5' 11"</div></td><td class="Table__TD"><div class="inline" style="min-width:70px">215 lbs</div></td><td class="Table__TD"><div class="inline">FR</div></td><td class="Table__TD"><div class="inline">Cedartown, GA</div></td></tr>
# <tr class="Table__TR Table__TR--lg Table__even" data-idx="13"><td class="Table__TD--headshot Table__TD"><div class="inline Table__TD--headshot" style="min-width:40px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4046826/darien-rencher" tabindex="0"><div class="headshot inline-block relative TableHeadshot roster-headshot headshot--sm athlete silo"><figure class="Image aspect-ratio--parent"><div class="RatioFrame aspect-ratio--1x1"></div><div class="Image__Wrapper aspect-ratio--child"><img alt="https://a.espncdn.com/i/headshots/college-football/players/full/4046826.png" class="" data-mptype="image" src="..." title="Darien Rencher"/></div></figure></div></a></div></td><td class="Table__TD"><div class="inline" style="min-width:140px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4046826/darien-rencher" tabindex="0">Darien Rencher</a><span class="pl2 n10">21</span></div></td><td class="Table__TD"><div class="inline">RB</div></td><td class="Table__TD"><div class="inline" style="min-width:50px">5' 8"</div></td><td class="Table__TD"><div class="inline" style="min-width:70px">195 lbs</div></td><td class="Table__TD"><div class="inline">SR</div></td><td class="Table__TD"><div class="inline">Anderson, SC</div></td></tr>
# <tr class="Table__TR Table__TR--lg Table__even" data-idx="14"><td class="Table__TD--headshot Table__TD"><div class="inline Table__TD--headshot" style="min-width:40px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4429207/ajou-ajou" tabindex="0"><div class="headshot inline-block relative TableHeadshot roster-headshot headshot--sm athlete silo"><figure class="Image aspect-ratio--parent"><div class="RatioFrame aspect-ratio--1x1"></div><div class="Image__Wrapper aspect-ratio--child"><img alt="https://a.espncdn.com/i/headshots/college-football/players/full/4429207.png" class="" data-mptype="image" src="..." title="Ajou Ajou"/></div></figure></div></a></div></td><td class="Table__TD"><div class="inline" style="min-width:140px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4429207/ajou-ajou" tabindex="0">Ajou Ajou</a><span class="pl2 n10">11</span></div></td><td class="Table__TD"><div class="inline">WR</div></td><td class="Table__TD"><div class="inline" style="min-width:50px">6' 4"</div></td><td class="Table__TD"><div class="inline" style="min-width:70px">220 lbs</div></td><td class="Table__TD"><div class="inline">FR</div></td><td class="Table__TD"><div class="inline">Brooks, AB</div></td></tr>
# <tr class="Table__TR Table__TR--lg Table__even" data-idx="15"><td class="Table__TD--headshot Table__TD"><div class="inline Table__TD--headshot" style="min-width:40px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4240009/will-brown" tabindex="0"><div class="headshot inline-block relative TableHeadshot roster-headshot headshot--sm athlete silo"><figure class="Image aspect-ratio--parent"><div class="RatioFrame aspect-ratio--1x1"></div><div class="Image__Wrapper aspect-ratio--child"><img alt="https://a.espncdn.com/i/headshots/college-football/players/full/4240009.png" class="" data-mptype="image" src="..." title="Will Brown"/></div></figure></div></a></div></td><td class="Table__TD"><div class="inline" style="min-width:140px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4240009/will-brown" tabindex="0">Will Brown</a><span class="pl2 n10">82</span></div></td><td class="Table__TD"><div class="inline">WR</div></td><td class="Table__TD"><div class="inline" style="min-width:50px">5' 8"</div></td><td class="Table__TD"><div class="inline" style="min-width:70px">180 lbs</div></td><td class="Table__TD"><div class="inline">JR</div></td><td class="Table__TD"><div class="inline">Boiling Springs, SC</div></td></tr>
# <tr class="Table__TR Table__TR--lg Table__even" data-idx="16"><td class="Table__TD--headshot Table__TD"><div class="inline Table__TD--headshot" style="min-width:40px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4568219/hampton-earle" tabindex="0"><div class="headshot inline-block relative TableHeadshot roster-headshot headshot--sm athlete silo"><figure class="Image aspect-ratio--parent"><div class="RatioFrame aspect-ratio--1x1"></div><div class="Image__Wrapper aspect-ratio--child"><img alt="https://a.espncdn.com/i/headshots/college-football/players/full/4568219.png" class="" data-mptype="image" src="..." title="Hampton Earle"/></div></figure></div></a></div></td><td class="Table__TD"><div class="inline" style="min-width:140px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4568219/hampton-earle" tabindex="0">Hampton Earle</a><span class="pl2 n10">83</span></div></td><td class="Table__TD"><div class="inline">WR</div></td><td class="Table__TD"><div class="inline" style="min-width:50px">5' 10"</div></td><td class="Table__TD"><div class="inline" style="min-width:70px">180 lbs</div></td><td class="Table__TD"><div class="inline">FR</div></td><td class="Table__TD"><div class="inline">Clemson, SC</div></td></tr>
# <tr class="Table__TR Table__TR--lg Table__even" data-idx="17"><td class="Table__TD--headshot Table__TD"><div class="inline Table__TD--headshot" style="min-width:40px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4568228/hamp-greene" tabindex="0"><div class="headshot inline-block relative TableHeadshot roster-headshot headshot--sm athlete silo"><figure class="Image aspect-ratio--parent"><div class="RatioFrame aspect-ratio--1x1"></div><div class="Image__Wrapper aspect-ratio--child"><img alt="https://a.espncdn.com/i/headshots/college-football/players/full/4568228.png" class="" data-mptype="image" src="..." title="Hamp Greene"/></div></figure></div></a></div></td><td class="Table__TD"><div class="inline" style="min-width:140px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4568228/hamp-greene" tabindex="0">Hamp Greene</a><span class="pl2 n10">87</span></div></td><td class="Table__TD"><div class="inline">WR</div></td><td class="Table__TD"><div class="inline" style="min-width:50px">5' 9"</div></td><td class="Table__TD"><div class="inline" style="min-width:70px">165 lbs</div></td><td class="Table__TD"><div class="inline">FR</div></td><td class="Table__TD"><div class="inline">Birmingham, AL</div></td></tr>
# <tr class="Table__TR Table__TR--lg Table__even" data-idx="18"><td class="Table__TD--headshot Table__TD"><div class="inline Table__TD--headshot" style="min-width:40px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4568227/tye-herbstreit" tabindex="0"><div class="headshot inline-block relative TableHeadshot roster-headshot headshot--sm athlete silo"><figure class="Image aspect-ratio--parent"><div class="RatioFrame aspect-ratio--1x1"></div><div class="Image__Wrapper aspect-ratio--child"><img alt="https://a.espncdn.com/i/headshots/college-football/players/full/4568227.png" class="" data-mptype="image" src="..." title="Tye Herbstreit"/></div></figure></div></a></div></td><td class="Table__TD"><div class="inline" style="min-width:140px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4568227/tye-herbstreit" tabindex="0">Tye Herbstreit</a><span class="pl2 n10">86</span></div></td><td class="Table__TD"><div class="inline">WR</div></td><td class="Table__TD"><div class="inline" style="min-width:50px">5' 10"</div></td><td class="Table__TD"><div class="inline" style="min-width:70px">165 lbs</div></td><td class="Table__TD"><div class="inline">FR</div></td><td class="Table__TD"><div class="inline">Nashville, TN</div></td></tr>
# <tr class="Table__TR Table__TR--lg Table__even" data-idx="19"><td class="Table__TD--headshot Table__TD"><div class="inline Table__TD--headshot" style="min-width:40px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4259209/josh-jackson" tabindex="0"><div class="headshot inline-block relative TableHeadshot roster-headshot headshot--sm athlete silo"><figure class="Image aspect-ratio--parent"><div class="RatioFrame aspect-ratio--1x1"></div><div class="Image__Wrapper aspect-ratio--child"><img alt="https://a.espncdn.com/i/headshots/college-football/players/full/4259209.png" class="" data-mptype="image" src="..." title="Josh Jackson"/></div></figure></div></a></div></td><td class="Table__TD"><div class="inline" style="min-width:140px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4259209/josh-jackson" tabindex="0">Josh Jackson</a><span class="pl2 n10">45</span></div></td><td class="Table__TD"><div class="inline">WR</div></td><td class="Table__TD"><div class="inline" style="min-width:50px">6' 1"</div></td><td class="Table__TD"><div class="inline" style="min-width:70px">190 lbs</div></td><td class="Table__TD"><div class="inline">SR</div></td><td class="Table__TD"><div class="inline">Greenville, SC</div></td></tr>
# <tr class="Table__TR Table__TR--lg Table__even" data-idx="20"><td class="Table__TD--headshot Table__TD"><div class="inline Table__TD--headshot" style="min-width:40px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4426343/frank-ladson-jr" tabindex="0"><div class="headshot inline-block relative TableHeadshot roster-headshot headshot--sm athlete silo"><figure class="Image aspect-ratio--parent"><div class="RatioFrame aspect-ratio--1x1"></div><div class="Image__Wrapper aspect-ratio--child"><img alt="https://a.espncdn.com/i/headshots/college-football/players/full/4426343.png" class="" data-mptype="image" src="..." title="Frank Ladson Jr."/></div></figure></div></a></div></td><td class="Table__TD"><div class="inline" style="min-width:140px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4426343/frank-ladson-jr" tabindex="0">Frank Ladson Jr.</a><span class="pl2 n10">2</span></div></td><td class="Table__TD"><div class="inline">WR</div></td><td class="Table__TD"><div class="inline" style="min-width:50px">6' 3"</div></td><td class="Table__TD"><div class="inline" style="min-width:70px">195 lbs</div></td><td class="Table__TD"><div class="inline">SO</div></td><td class="Table__TD"><div class="inline">Miami, FL</div></td></tr>
# <tr class="Table__TR Table__TR--lg Table__even" data-idx="21"><td class="Table__TD--headshot Table__TD"><div class="inline Table__TD--headshot" style="min-width:40px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4360322/max-may" tabindex="0"><div class="headshot inline-block relative TableHeadshot roster-headshot headshot--sm athlete silo"><figure class="Image aspect-ratio--parent"><div class="RatioFrame aspect-ratio--1x1"></div><div class="Image__Wrapper aspect-ratio--child"><img alt="https://a.espncdn.com/i/headshots/college-football/players/full/4360322.png" class="" data-mptype="image" src="..." title="Max May"/></div></figure></div></a></div></td><td class="Table__TD"><div class="inline" style="min-width:140px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4360322/max-may" tabindex="0">Max May</a><span class="pl2 n10">89</span></div></td><td class="Table__TD"><div class="inline">WR</div></td><td class="Table__TD"><div class="inline" style="min-width:50px">6' 1"</div></td><td class="Table__TD"><div class="inline" style="min-width:70px">190 lbs</div></td><td class="Table__TD"><div class="inline">SO</div></td><td class="Table__TD"><div class="inline">Clemson, SC</div></td></tr>
# <tr class="Table__TR Table__TR--lg Table__even" data-idx="22"><td class="Table__TD--headshot Table__TD"><div class="inline Table__TD--headshot" style="min-width:40px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4426426/joseph-ngata" tabindex="0"><div class="headshot inline-block relative TableHeadshot roster-headshot headshot--sm athlete silo"><figure class="Image aspect-ratio--parent"><div class="RatioFrame aspect-ratio--1x1"></div><div class="Image__Wrapper aspect-ratio--child"><img alt="https://a.espncdn.com/i/headshots/college-football/players/full/4426426.png" class="" data-mptype="image" src="..." title="Joseph Ngata"/></div></figure></div></a></div></td><td class="Table__TD"><div class="inline" style="min-width:140px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4426426/joseph-ngata" tabindex="0">Joseph Ngata</a><span class="pl2 n10">10</span></div></td><td class="Table__TD"><div class="inline">WR</div></td><td class="Table__TD"><div class="inline" style="min-width:50px">6' 3"</div></td><td class="Table__TD"><div class="inline" style="min-width:70px">215 lbs</div></td><td class="Table__TD"><div class="inline">SO</div></td><td class="Table__TD"><div class="inline">Folsom, CA</div></td></tr>
# <tr class="Table__TR Table__TR--lg Table__even" data-idx="23"><td class="Table__TD--headshot Table__TD"><div class="inline Table__TD--headshot" style="min-width:40px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4035465/cornell-powell" tabindex="0"><div class="headshot inline-block relative TableHeadshot roster-headshot headshot--sm athlete silo"><figure class="Image aspect-ratio--parent"><div class="RatioFrame aspect-ratio--1x1"></div><div class="Image__Wrapper aspect-ratio--child"><img alt="https://a.espncdn.com/i/headshots/college-football/players/full/4035465.png" class="" data-mptype="image" src="..." title="Cornell Powell"/></div></figure></div></a></div></td><td class="Table__TD"><div class="inline" style="min-width:140px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4035465/cornell-powell" tabindex="0">Cornell Powell</a><span class="pl2 n10">17</span></div></td><td class="Table__TD"><div class="inline">WR</div></td><td class="Table__TD"><div class="inline" style="min-width:50px">6' 0"</div></td><td class="Table__TD"><div class="inline" style="min-width:70px">210 lbs</div></td><td class="Table__TD"><div class="inline">SR</div></td><td class="Table__TD"><div class="inline">Greenville, NC</div></td></tr>
# <tr class="Table__TR Table__TR--lg Table__even" data-idx="24"><td class="Table__TD--headshot Table__TD"><div class="inline Table__TD--headshot" style="min-width:40px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4239992/amari-rodgers" tabindex="0"><div class="headshot inline-block relative TableHeadshot roster-headshot headshot--sm athlete silo"><figure class="Image aspect-ratio--parent"><div class="RatioFrame aspect-ratio--1x1"></div><div class="Image__Wrapper aspect-ratio--child"><img alt="https://a.espncdn.com/i/headshots/college-football/players/full/4239992.png" class="" data-mptype="image" src="..." title="Amari Rodgers"/></div></figure></div></a></div></td><td class="Table__TD"><div class="inline" style="min-width:140px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4239992/amari-rodgers" tabindex="0">Amari Rodgers</a><span class="pl2 n10">3</span></div></td><td class="Table__TD"><div class="inline">WR</div></td><td class="Table__TD"><div class="inline" style="min-width:50px">5' 10"</div></td><td class="Table__TD"><div class="inline" style="min-width:70px">210 lbs</div></td><td class="Table__TD"><div class="inline">SR</div></td><td class="Table__TD"><div class="inline">Knoxville, TN</div></td></tr>
# <tr class="Table__TR Table__TR--lg Table__even" data-idx="25"><td class="Table__TD--headshot Table__TD"><div class="inline Table__TD--headshot" style="min-width:40px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4360306/justyn-ross" tabindex="0"><div class="headshot inline-block relative TableHeadshot roster-headshot headshot--sm athlete silo"><figure class="Image aspect-ratio--parent"><div class="RatioFrame aspect-ratio--1x1"></div><div class="Image__Wrapper aspect-ratio--child"><img alt="https://a.espncdn.com/i/headshots/college-football/players/full/4360306.png" class="" data-mptype="image" src="..." title="Justyn Ross"/></div></figure></div></a></div></td><td class="Table__TD"><div class="inline" style="min-width:140px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4360306/justyn-ross" tabindex="0">Justyn Ross</a><span class="pl2 n10">8</span></div></td><td class="Table__TD"><div class="inline">WR</div></td><td class="Table__TD"><div class="inline" style="min-width:50px">6' 4"</div></td><td class="Table__TD"><div class="inline" style="min-width:70px">205 lbs</div></td><td class="Table__TD"><div class="inline">JR</div></td><td class="Table__TD"><div class="inline">Phenix City, AL</div></td></tr>
# <tr class="Table__TR Table__TR--lg Table__even" data-idx="26"><td class="Table__TD--headshot Table__TD"><div class="inline Table__TD--headshot" style="min-width:40px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4430518/brannon-spector" tabindex="0"><div class="headshot inline-block relative TableHeadshot roster-headshot headshot--sm athlete silo"><figure class="Image aspect-ratio--parent"><div class="RatioFrame aspect-ratio--1x1"></div><div class="Image__Wrapper aspect-ratio--child"><img alt="https://a.espncdn.com/i/headshots/college-football/players/full/4430518.png" class="" data-mptype="image" src="..." title="Brannon Spector"/></div></figure></div></a></div></td><td class="Table__TD"><div class="inline" style="min-width:140px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4430518/brannon-spector" tabindex="0">Brannon Spector</a><span class="pl2 n10">13</span></div></td><td class="Table__TD"><div class="inline">WR</div></td><td class="Table__TD"><div class="inline" style="min-width:50px">6' 1"</div></td><td class="Table__TD"><div class="inline" style="min-width:70px">195 lbs</div></td><td class="Table__TD"><div class="inline">FR</div></td><td class="Table__TD"><div class="inline">Calhoun, GA</div></td></tr>
# <tr class="Table__TR Table__TR--lg Table__even" data-idx="27"><td class="Table__TD--headshot Table__TD"><div class="inline Table__TD--headshot" style="min-width:40px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4360321/drew-swinney" tabindex="0"><div class="headshot inline-block relative TableHeadshot roster-headshot headshot--sm athlete silo"><figure class="Image aspect-ratio--parent"><div class="RatioFrame aspect-ratio--1x1"></div><div class="Image__Wrapper aspect-ratio--child"><img alt="https://a.espncdn.com/i/headshots/college-football/players/full/4360321.png" class="" data-mptype="image" src="..." title="Drew Swinney"/></div></figure></div></a></div></td><td class="Table__TD"><div class="inline" style="min-width:140px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4360321/drew-swinney" tabindex="0">Drew Swinney</a><span class="pl2 n10">81</span></div></td><td class="Table__TD"><div class="inline">WR</div></td><td class="Table__TD"><div class="inline" style="min-width:50px">5' 8"</div></td><td class="Table__TD"><div class="inline" style="min-width:70px">180 lbs</div></td><td class="Table__TD"><div class="inline">SO</div></td><td class="Table__TD"><div class="inline">Clemson, SC</div></td></tr>
# <tr class="Table__TR Table__TR--lg Table__even" data-idx="28"><td class="Table__TD--headshot Table__TD"><div class="inline Table__TD--headshot" style="min-width:40px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4239999/will-swinney" tabindex="0"><div class="headshot inline-block relative TableHeadshot roster-headshot headshot--sm athlete silo"><figure class="Image aspect-ratio--parent"><div class="RatioFrame aspect-ratio--1x1"></div><div class="Image__Wrapper aspect-ratio--child"><img alt="https://a.espncdn.com/i/headshots/college-football/players/full/4239999.png" class="" data-mptype="image" src="..." title="Will Swinney"/></div></figure></div></a></div></td><td class="Table__TD"><div class="inline" style="min-width:140px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4239999/will-swinney" tabindex="0">Will Swinney</a><span class="pl2 n10">22</span></div></td><td class="Table__TD"><div class="inline">WR</div></td><td class="Table__TD"><div class="inline" style="min-width:50px">5' 8"</div></td><td class="Table__TD"><div class="inline" style="min-width:70px">185 lbs</div></td><td class="Table__TD"><div class="inline">SR</div></td><td class="Table__TD"><div class="inline">Clemson, SC</div></td></tr>
# <tr class="Table__TR Table__TR--lg Table__even" data-idx="29"><td class="Table__TD--headshot Table__TD"><div class="inline Table__TD--headshot" style="min-width:40px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4686093/ej-williams" tabindex="0"><div class="headshot inline-block relative TableHeadshot roster-headshot headshot--sm athlete silo"><figure class="Image aspect-ratio--parent"><div class="RatioFrame aspect-ratio--1x1"></div><div class="Image__Wrapper aspect-ratio--child"><img alt="https://a.espncdn.com/i/headshots/college-football/players/full/4686093.png" class="" data-mptype="image" src="..." title="E.J. Williams"/></div></figure></div></a></div></td><td class="Table__TD"><div class="inline" style="min-width:140px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4686093/ej-williams" tabindex="0">E.J. Williams</a><span class="pl2 n10">6</span></div></td><td class="Table__TD"><div class="inline">WR</div></td><td class="Table__TD"><div class="inline" style="min-width:50px">6' 4"</div></td><td class="Table__TD"><div class="inline" style="min-width:70px">190 lbs</div></td><td class="Table__TD"><div class="inline">FR</div></td><td class="Table__TD"><div class="inline">Phenix City, AL</div></td></tr>
# <tr class="Table__TR Table__TR--lg Table__even" data-idx="30"><td class="Table__TD--headshot Table__TD"><div class="inline Table__TD--headshot" style="min-width:40px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4426553/davis-allen" tabindex="0"><div class="headshot inline-block relative TableHeadshot roster-headshot headshot--sm athlete silo"><figure class="Image aspect-ratio--parent"><div class="RatioFrame aspect-ratio--1x1"></div><div class="Image__Wrapper aspect-ratio--child"><img alt="https://a.espncdn.com/i/headshots/college-football/players/full/4426553.png" class="" data-mptype="image" src="..." title="Davis Allen"/></div></figure></div></a></div></td><td class="Table__TD"><div class="inline" style="min-width:140px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4426553/davis-allen" tabindex="0">Davis Allen</a><span class="pl2 n10">84</span></div></td><td class="Table__TD"><div class="inline">TE</div></td><td class="Table__TD"><div class="inline" style="min-width:50px">6' 6"</div></td><td class="Table__TD"><div class="inline" style="min-width:70px">240 lbs</div></td><td class="Table__TD"><div class="inline">SO</div></td><td class="Table__TD"><div class="inline">Calhoun, GA</div></td></tr>
# <tr class="Table__TR Table__TR--lg Table__even" data-idx="31"><td class="Table__TD--headshot Table__TD"><div class="inline Table__TD--headshot" style="min-width:40px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4686098/will-blackston" tabindex="0"><div class="headshot inline-block relative TableHeadshot roster-headshot headshot--sm athlete silo"><figure class="Image aspect-ratio--parent"><div class="RatioFrame aspect-ratio--1x1"></div><div class="Image__Wrapper aspect-ratio--child"><img alt="https://a.espncdn.com/i/headshots/college-football/players/full/4686098.png" class="" data-mptype="image" src="..." title="Will Blackston"/></div></figure></div></a></div></td><td class="Table__TD"><div class="inline" style="min-width:140px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4686098/will-blackston" tabindex="0">Will Blackston</a><span class="pl2 n10">43</span></div></td><td class="Table__TD"><div class="inline">TE</div></td><td class="Table__TD"><div class="inline" style="min-width:50px">6' 1"</div></td><td class="Table__TD"><div class="inline" style="min-width:70px">235 lbs</div></td><td class="Table__TD"><div class="inline">FR</div></td><td class="Table__TD"><div class="inline">Honea Path, SC</div></td></tr>
# <tr class="Table__TR Table__TR--lg Table__even" data-idx="32"><td class="Table__TD--headshot Table__TD"><div class="inline Table__TD--headshot" style="min-width:40px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4035469/jc-chalk" tabindex="0"><div class="headshot inline-block relative TableHeadshot roster-headshot headshot--sm athlete silo"><figure class="Image aspect-ratio--parent"><div class="RatioFrame aspect-ratio--1x1"></div><div class="Image__Wrapper aspect-ratio--child"><img alt="https://a.espncdn.com/i/headshots/college-football/players/full/4035469.png" class="" data-mptype="image" src="..." title="J.C. Chalk"/></div></figure></div></a></div></td><td class="Table__TD"><div class="inline" style="min-width:140px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4035469/jc-chalk" tabindex="0">J.C. Chalk</a><span class="pl2 n10">25</span></div></td><td class="Table__TD"><div class="inline">TE</div></td><td class="Table__TD"><div class="inline" style="min-width:50px">6' 3"</div></td><td class="Table__TD"><div class="inline" style="min-width:70px">255 lbs</div></td><td class="Table__TD"><div class="inline">SR</div></td><td class="Table__TD"><div class="inline">Argyle, TX</div></td></tr>
# <tr class="Table__TR Table__TR--lg Table__even" data-idx="33"><td class="Table__TD--headshot Table__TD"><div class="inline Table__TD--headshot" style="min-width:40px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4431081/sage-ennis" tabindex="0"><div class="headshot inline-block relative TableHeadshot roster-headshot headshot--sm athlete silo"><figure class="Image aspect-ratio--parent"><div class="RatioFrame aspect-ratio--1x1"></div><div class="Image__Wrapper aspect-ratio--child"><img alt="https://a.espncdn.com/i/headshots/college-football/players/full/4431081.png" class="" data-mptype="image" src="..." title="Sage Ennis"/></div></figure></div></a></div></td><td class="Table__TD"><div class="inline" style="min-width:140px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4431081/sage-ennis" tabindex="0">Sage Ennis</a><span class="pl2 n10">87</span></div></td><td class="Table__TD"><div class="inline">TE</div></td><td class="Table__TD"><div class="inline" style="min-width:50px">6' 4"</div></td><td class="Table__TD"><div class="inline" style="min-width:70px">230 lbs</div></td><td class="Table__TD"><div class="inline">FR</div></td><td class="Table__TD"><div class="inline">Graceville, FL</div></td></tr>
# <tr class="Table__TR Table__TR--lg Table__even" data-idx="34"><td class="Table__TD--headshot Table__TD"><div class="inline Table__TD--headshot" style="min-width:40px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4360323/braden-galloway" tabindex="0"><div class="headshot inline-block relative TableHeadshot roster-headshot headshot--sm athlete silo"><figure class="Image aspect-ratio--parent"><div class="RatioFrame aspect-ratio--1x1"></div><div class="Image__Wrapper aspect-ratio--child"><img alt="https://a.espncdn.com/i/headshots/college-football/players/full/4360323.png" class="" data-mptype="image" src="..." title="Braden Galloway"/></div></figure></div></a></div></td><td class="Table__TD"><div class="inline" style="min-width:140px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4360323/braden-galloway" tabindex="0">Braden Galloway</a><span class="pl2 n10">88</span></div></td><td class="Table__TD"><div class="inline">TE</div></td><td class="Table__TD"><div class="inline" style="min-width:50px">6' 4"</div></td><td class="Table__TD"><div class="inline" style="min-width:70px">240 lbs</div></td><td class="Table__TD"><div class="inline">JR</div></td><td class="Table__TD"><div class="inline">Anderson, SC</div></td></tr>
# <tr class="Table__TR Table__TR--lg Table__even" data-idx="35"><td class="Table__TD--headshot Table__TD"><div class="inline Table__TD--headshot" style="min-width:40px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4427779/jaelyn-lay" tabindex="0"><div class="headshot inline-block relative TableHeadshot roster-headshot headshot--sm athlete silo"><figure class="Image aspect-ratio--parent"><div class="RatioFrame aspect-ratio--1x1"></div><div class="Image__Wrapper aspect-ratio--child"><img alt="https://a.espncdn.com/i/headshots/college-football/players/full/4427779.png" class="" data-mptype="image" src="..." title="Jaelyn Lay"/></div></figure></div></a></div></td><td class="Table__TD"><div class="inline" style="min-width:140px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4427779/jaelyn-lay" tabindex="0">Jaelyn Lay</a><span class="pl2 n10">85</span></div></td><td class="Table__TD"><div class="inline">TE</div></td><td class="Table__TD"><div class="inline" style="min-width:50px">6' 6"</div></td><td class="Table__TD"><div class="inline" style="min-width:70px">270 lbs</div></td><td class="Table__TD"><div class="inline">FR</div></td><td class="Table__TD"><div class="inline">Atlanta, GA</div></td></tr>
# <tr class="Table__TR Table__TR--lg Table__even" data-idx="36"><td class="Table__TD--headshot Table__TD"><div class="inline Table__TD--headshot" style="min-width:40px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4240003/luke-price" tabindex="0"><div class="headshot inline-block relative TableHeadshot roster-headshot headshot--sm athlete silo"><figure class="Image aspect-ratio--parent"><div class="RatioFrame aspect-ratio--1x1"></div><div class="Image__Wrapper aspect-ratio--child"><img alt="https://a.espncdn.com/i/headshots/college-football/players/full/4240003.png" class="" data-mptype="image" src="..." title="Luke Price"/></div></figure></div></a></div></td><td class="Table__TD"><div class="inline" style="min-width:140px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4240003/luke-price" tabindex="0">Luke Price</a><span class="pl2 n10">80</span></div></td><td class="Table__TD"><div class="inline">TE</div></td><td class="Table__TD"><div class="inline" style="min-width:50px">6' 2"</div></td><td class="Table__TD"><div class="inline" style="min-width:70px">230 lbs</div></td><td class="Table__TD"><div class="inline">JR</div></td><td class="Table__TD"><div class="inline">Dillon, SC</div></td></tr>
# ...
# <tr class="Table__TR Table__TR--lg Table__even" data-idx="45"><td class="Table__TD--headshot Table__TD"><div class="inline Table__TD--headshot" style="min-width:40px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4429044/walker-parks" tabindex="0"><div class="headshot inline-block relative TableHeadshot roster-headshot headshot--sm athlete silo"><figure class="Image aspect-ratio--parent"><div class="RatioFrame aspect-ratio--1x1"></div><div class="Image__Wrapper aspect-ratio--child"><img alt="https://a.espncdn.com/i/headshots/college-football/players/full/4429044.png" class="" data-mptype="image" src="..." title="Walker Parks"/></div></figure></div></a></div></td><td class="Table__TD"><div class="inline" style="min-width:140px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4429044/walker-parks" tabindex="0">Walker Parks</a><span class="pl2 n10">64</span></div></td><td class="Table__TD"><div class="inline">OL</div></td><td class="Table__TD"><div class="inline" style="min-width:50px">6' 5"</div></td><td class="Table__TD"><div class="inline" style="min-width:70px">275 lbs</div></td><td class="Table__TD"><div class="inline">FR</div></td><td class="Table__TD"><div class="inline">Lexington, KY</div></td></tr>
# <tr class="Table__TR Table__TR--lg Table__even" data-idx="46"><td class="Table__TD--headshot Table__TD"><div class="inline Table__TD--headshot" style="min-width:40px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4426393/will-putnam" tabindex="0"><div class="headshot inline-block relative TableHeadshot roster-headshot headshot--sm athlete silo"><figure class="Image aspect-ratio--parent"><div class="RatioFrame aspect-ratio--1x1"></div><div class="Image__Wrapper aspect-ratio--child"><img alt="https://a.espncdn.com/i/headshots/college-football/players/full/4426393.png" class="" data-mptype="image" src="..." title="Will Putnam"/></div></figure></div></a></div></td><td class="Table__TD"><div class="inline" style="min-width:140px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4426393/will-putnam" tabindex="0">Will Putnam</a><span class="pl2 n10">56</span></div></td><td class="Table__TD"><div class="inline">OL</div></td><td class="Table__TD"><div class="inline" style="min-width:50px">6' 4"</div></td><td class="Table__TD"><div class="inline" style="min-width:70px">295 lbs</div></td><td class="Table__TD"><div class="inline">SO</div></td><td class="Table__TD"><div class="inline">Tampa, FL</div></td></tr>
# <tr class="Table__TR Table__TR--lg Table__even" data-idx="47"><td class="Table__TD--headshot Table__TD"><div class="inline Table__TD--headshot" style="min-width:40px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4428311/hunter-rayburn" tabindex="0"><div class="headshot inline-block relative TableHeadshot roster-headshot headshot--sm athlete silo"><figure class="Image aspect-ratio--parent"><div class="RatioFrame aspect-ratio--1x1"></div><div class="Image__Wrapper aspect-ratio--child"><img alt="https://a.espncdn.com/i/headshots/college-football/players/full/4428311.png" class="" data-mptype="image" src="..." title="Hunter Rayburn"/></div></figure></div></a></div></td><td class="Table__TD"><div class="inline" style="min-width:140px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4428311/hunter-rayburn" tabindex="0">Hunter Rayburn</a><span class="pl2 n10">55</span></div></td><td class="Table__TD"><div class="inline">OL</div></td><td class="Table__TD"><div class="inline" style="min-width:50px">6' 4"</div></td><td class="Table__TD"><div class="inline" style="min-width:70px">315 lbs</div></td><td class="Table__TD"><div class="inline">FR</div></td><td class="Table__TD"><div class="inline">Pensacola, FL</div></td></tr>
# <tr class="Table__TR Table__TR--lg Table__even" data-idx="48"><td class="Table__TD--headshot Table__TD"><div class="inline Table__TD--headshot" style="min-width:40px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4035477/cade-stewart" tabindex="0"><div class="headshot inline-block relative TableHeadshot roster-headshot headshot--sm athlete silo"><figure class="Image aspect-ratio--parent"><div class="RatioFrame aspect-ratio--1x1"></div><div class="Image__Wrapper aspect-ratio--child"><img alt="https://a.espncdn.com/i/headshots/college-football/players/full/4035477.png" class="" data-mptype="image" src="..." title="Cade Stewart"/></div></figure></div></a></div></td><td class="Table__TD"><div class="inline" style="min-width:140px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4035477/cade-stewart" tabindex="0">Cade Stewart</a><span class="pl2 n10">62</span></div></td><td class="Table__TD"><div class="inline">OL</div></td><td class="Table__TD"><div class="inline" style="min-width:50px">6' 3"</div></td><td class="Table__TD"><div class="inline" style="min-width:70px">305 lbs</div></td><td class="Table__TD"><div class="inline">SR</div></td><td class="Table__TD"><div class="inline">Six Mile, SC</div></td></tr>
# <tr class="Table__TR Table__TR--lg Table__even" data-idx="49"><td class="Table__TD--headshot Table__TD"><div class="inline Table__TD--headshot" style="min-width:40px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4430839/paul-tchio" tabindex="0"><div class="headshot inline-block relative TableHeadshot roster-headshot headshot--sm athlete silo"><figure class="Image aspect-ratio--parent"><div class="RatioFrame aspect-ratio--1x1"></div><div class="Image__Wrapper aspect-ratio--child"><img alt="https://a.espncdn.com/i/headshots/college-football/players/full/4430839.png" class="" data-mptype="image" src="..." title="Paul Tchio"/></div></figure></div></a></div></td><td class="Table__TD"><div class="inline" style="min-width:140px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4430839/paul-tchio" tabindex="0">Paul Tchio</a><span class="pl2 n10">57</span></div></td><td class="Table__TD"><div class="inline">OL</div></td><td class="Table__TD"><div class="inline" style="min-width:50px">6' 5"</div></td><td class="Table__TD"><div class="inline" style="min-width:70px">300 lbs</div></td><td class="Table__TD"><div class="inline">FR</div></td><td class="Table__TD"><div class="inline">Milton, GA</div></td></tr>
# <tr class="Table__TR Table__TR--lg Table__even" data-idx="50"><td class="Table__TD--headshot Table__TD"><div class="inline Table__TD--headshot" style="min-width:40px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4428706/mason-trotter" tabindex="0"><div class="headshot inline-block relative TableHeadshot roster-headshot headshot--sm athlete silo"><figure class="Image aspect-ratio--parent"><div class="RatioFrame aspect-ratio--1x1"></div><div class="Image__Wrapper aspect-ratio--child"><img alt="https://a.espncdn.com/i/headshots/college-football/players/full/4428706.png" class="" data-mptype="image" src="..." title="Mason Trotter"/></div></figure></div></a></div></td><td class="Table__TD"><div class="inline" style="min-width:140px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4428706/mason-trotter" tabindex="0">Mason Trotter</a><span class="pl2 n10">54</span></div></td><td class="Table__TD"><div class="inline">OL</div></td><td class="Table__TD"><div class="inline" style="min-width:50px">6' 2"</div></td><td class="Table__TD"><div class="inline" style="min-width:70px">270 lbs</div></td><td class="Table__TD"><div class="inline">FR</div></td><td class="Table__TD"><div class="inline">Roebuck, SC</div></td></tr>
# <tr class="Table__TR Table__TR--lg Table__even" data-idx="51"><td class="Table__TD--headshot Table__TD"><div class="inline Table__TD--headshot" style="min-width:40px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4430837/bryn-tucker" tabindex="0"><div class="headshot inline-block relative TableHeadshot roster-headshot headshot--sm athlete silo"><figure class="Image aspect-ratio--parent"><div class="RatioFrame aspect-ratio--1x1"></div><div class="Image__Wrapper aspect-ratio--child"><img alt="https://a.espncdn.com/i/headshots/college-football/players/full/4430837.png" class="" data-mptype="image" src="..." title="Bryn Tucker"/></div></figure></div></a></div></td><td class="Table__TD"><div class="inline" style="min-width:140px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4430837/bryn-tucker" tabindex="0">Bryn Tucker</a><span class="pl2 n10">73</span></div></td><td class="Table__TD"><div class="inline">OL</div></td><td class="Table__TD"><div class="inline" style="min-width:50px">6' 5"</div></td><td class="Table__TD"><div class="inline" style="min-width:70px">290 lbs</div></td><td class="Table__TD"><div class="inline">FR</div></td><td class="Table__TD"><div class="inline">Knoxville, TN</div></td></tr>
# <tr class="Table__TR Table__TR--lg Table__even" data-idx="52"><td class="Table__TD--headshot Table__TD"><div class="inline Table__TD--headshot" style="min-width:40px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4240008/blake-vinson" tabindex="0"><div class="headshot inline-block relative TableHeadshot roster-headshot headshot--sm athlete silo"><figure class="Image aspect-ratio--parent"><div class="RatioFrame aspect-ratio--1x1"></div><div class="Image__Wrapper aspect-ratio--child"><img alt="https://a.espncdn.com/i/headshots/college-football/players/full/4240008.png" class="" data-mptype="image" src="..." title="Blake Vinson"/></div></figure></div></a></div></td><td class="Table__TD"><div class="inline" style="min-width:140px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4240008/blake-vinson" tabindex="0">Blake Vinson</a><span class="pl2 n10">72</span></div></td><td class="Table__TD"><div class="inline">OL</div></td><td class="Table__TD"><div class="inline" style="min-width:50px">6' 4"</div></td><td class="Table__TD"><div class="inline" style="min-width:70px">300 lbs</div></td><td class="Table__TD"><div class="inline">SO</div></td><td class="Table__TD"><div class="inline">Ocala, FL</div></td></tr>
# <tr class="Table__TR Table__TR--lg Table__even" data-idx="53"><td class="Table__TD--headshot Table__TD"><div class="inline Table__TD--headshot" style="min-width:40px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4686101/john-williams" tabindex="0"><div class="headshot inline-block relative TableHeadshot roster-headshot headshot--sm athlete silo"><figure class="Image aspect-ratio--parent"><div class="RatioFrame aspect-ratio--1x1"></div><div class="Image__Wrapper aspect-ratio--child"><img alt="https://a.espncdn.com/i/headshots/college-football/players/full/4686101.png" class="" data-mptype="image" src="..." title="John Williams"/></div></figure></div></a></div></td><td class="Table__TD"><div class="inline" style="min-width:140px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4686101/john-williams" tabindex="0">John Williams</a><span class="pl2 n10">76</span></div></td><td class="Table__TD"><div class="inline">OL</div></td><td class="Table__TD"><div class="inline" style="min-width:50px">6' 5"</div></td><td class="Table__TD"><div class="inline" style="min-width:70px">280 lbs</div></td><td class="Table__TD"><div class="inline">FR</div></td><td class="Table__TD"><div class="inline">Canton, GA</div></td></tr>
# <tr class="Table__TR Table__TR--lg Table__even" data-idx="54"><td class="Table__TD--headshot Table__TD"><div class="inline Table__TD--headshot" style="min-width:40px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4360320/jackson-carman" tabindex="0"><div class="headshot inline-block relative TableHeadshot roster-headshot headshot--sm athlete silo"><figure class="Image aspect-ratio--parent"><div class="RatioFrame aspect-ratio--1x1"></div><div class="Image__Wrapper aspect-ratio--child"><img alt="https://a.espncdn.com/i/headshots/college-football/players/full/4360320.png" class="" data-mptype="image" src="..." title="Jackson Carman"/></div></figure></div></a></div></td><td class="Table__TD"><div class="inline" style="min-width:140px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4360320/jackson-carman" tabindex="0">Jackson Carman</a><span class="pl2 n10">79</span></div></td><td class="Table__TD"><div class="inline">OT</div></td><td class="Table__TD"><div class="inline" style="min-width:50px">6' 5"</div></td><td class="Table__TD"><div class="inline" style="min-width:70px">345 lbs</div></td><td class="Table__TD"><div class="inline">JR</div></td><td class="Table__TD"><div class="inline">Fairfield, OH</div></td></tr>
# <tr class="Table__TR Table__TR--lg Table__even" data-idx="55"><td class="Table__TD--headshot Table__TD"><div class="inline Table__TD--headshot" style="min-width:40px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4454023/will-edwards" tabindex="0"><div class="headshot inline-block relative TableHeadshot roster-headshot headshot--sm athlete silo"><figure class="Image aspect-ratio--parent"><div class="RatioFrame aspect-ratio--1x1"></div><div class="Image__Wrapper aspect-ratio--child"><img alt="https://a.espncdn.com/i/headshots/college-football/players/full/4454023.png" class="" data-mptype="image" src="..." title="Will Edwards"/></div></figure></div></a></div></td><td class="Table__TD"><div class="inline" style="min-width:140px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4454023/will-edwards" tabindex="0">Will Edwards</a><span class="pl2 n10">67</span></div></td><td class="Table__TD"><div class="inline">OT</div></td><td class="Table__TD"><div class="inline" style="min-width:50px">6' 5"</div></td><td class="Table__TD"><div class="inline" style="min-width:70px">255 lbs</div></td><td class="Table__TD"><div class="inline">SO</div></td><td class="Table__TD"><div class="inline">Greenville, SC</div></td></tr>
# <tr class="Table__TR Table__TR--lg Table__even" data-idx="56"><td class="Table__TD--headshot Table__TD"><div class="inline Table__TD--headshot" style="min-width:40px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4360319/jordan-mcfadden" tabindex="0"><div class="headshot inline-block relative TableHeadshot roster-headshot headshot--sm athlete silo"><figure class="Image aspect-ratio--parent"><div class="RatioFrame aspect-ratio--1x1"></div><div class="Image__Wrapper aspect-ratio--child"><img alt="https://a.espncdn.com/i/headshots/college-football/players/full/4360319.png" class="" data-mptype="image" src="..." title="Jordan McFadden"/></div></figure></div></a></div></td><td class="Table__TD"><div class="inline" style="min-width:140px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4360319/jordan-mcfadden" tabindex="0">Jordan McFadden</a><span class="pl2 n10">71</span></div></td><td class="Table__TD"><div class="inline">OT</div></td><td class="Table__TD"><div class="inline" style="min-width:50px">6' 2"</div></td><td class="Table__TD"><div class="inline" style="min-width:70px">295 lbs</div></td><td class="Table__TD"><div class="inline">SO</div></td><td class="Table__TD"><div class="inline">Spartanburg, SC</div></td></tr>

# %%
len(tables)
# Out:
# 3

# %%
### Find the three tables for groups: Offense, Defense, and Special Teams

# %%
soup.find_all(class_="Table__Title")
# Out:
# [<div class="Table__Title">Offense</div>,
#  <div class="Table__Title">Defense</div>,
#  <div class="Table__Title">Special Teams</div>]

# %% [markdown]
# ## Find the Offense Players Table

# %%
soup.find_all(class_="Table__Title", string="Offense")
# Out:
# [<div class="Table__Title">Offense</div>]

# %%
soup.find(class_="Table__Title", string="Offense")
# Out:
# <div class="Table__Title">Offense</div>

# %%
soup.find(class_="Table__Title", string="Offense").find_next("table")
# Out:
# <table class="Table" style="border-collapse:collapse;border-spacing:0"><colgroup class="Table__Colgroup"><col class="Table__Column"/><col class="Table__Column"/><col class="Table__Column"/><col class="Table__Column"/><col class="Table__Column"/><col class="Table__Column"/><col class="Table__Column"/></colgroup><thead class="Table__header-group Table__THEAD"><tr class="Table__sub-header Table__TR Table__even"><th class="Table__TD--headshot Table__TH" title=""><span class="fw-medium w-100 dib Table__TD--headshot" style="min-width:40px" title=""></span></th><th class="Table__TH" title=""><span class="fw-medium w-100 dib" style="min-width:140px" title="">Name</span></th><th class="Table__TH" title=""><span class="fw-medium w-100 dib underline" title=""><a class="AnchorLink clr-gray-04" href="/college-football/team/roster/_/id/228/sort/position/dir/asc/clemson-tigers" tabindex="0">POS</a></span></th><th class="Table__TH" title=""><span class="fw-medium w-100 dib underline" style="min-width:50px" title=""><a class="AnchorLink clr-gray-04" href="/college-football/team/roster/_/id/228/sort/height/dir/asc/clemson-tigers" tabindex="0">HT</a></span></th><th class="Table__TH" title=""><span class="fw-medium w-100 dib underline" style="min-width:70px" title=""><a class="AnchorLink clr-gray-04" href="/college-football/team/roster/_/id/228/sort/weight/dir/asc/clemson-tigers" tabindex="0">WT</a></span></th><th class="Table__TH" title=""><span class="fw-medium w-100 dib underline" title=""><a class="AnchorLink clr-gray-04" href="/college-football/team/roster/_/id/228/sort/experience/dir/asc/clemson-tigers" tabindex="0">Class</a></span></th><th class="Table__TH" title=""><span class="fw-medium w-100 dib" title="">Birthplace</span></th></tr></thead><tbody class="Table__TBODY"><tr class="Table__TR Table__TR--lg Table__even" data-idx="0"><td class="Table__TD--headshot Table__TD"><div class="inline Table__TD--headshot" style="min-width:40px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4686096/hunter-helms" tabindex="0"><div class="headshot inline-block relative TableHeadshot roster-headshot headshot--sm athlete silo"><figure class="Image aspect-ratio--parent"><div class="RatioFrame aspect-ratio--1x1"></div><div class="Image__Wrapper aspect-ratio--child"><img alt="https://a.espncdn.com/i/headshots/college-football/players/full/4686096.png" class="" data-mptype="image" src="..." title="Hunter Helms"/></div></figure></div></a></div></td><td class="Table__TD"><div class="inline" style="min-width:140px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4686096/hunter-helms" tabindex="0">Hunter Helms</a><span class="pl2 n10">18</span></div></td><td class="Table__TD"><div class="inline">QB</div></td><td class="Table__TD"><div class="inline" style="min-width:50px">6' 2"</div></td><td class="Table__TD"><div class="inline" style="min-width:70px">210 lbs</div></td><td class="Table__TD"><div class="inline">FR</div></td><td class="Table__TD"><div class="inline">West Columbia, SC</div></td></tr><tr class="Table__TR Table__TR--lg Table__even" data-idx="1"><td class="Table__TD--headshot Table__TD"><div class="inline Table__TD--headshot" style="min-width:40px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4360310/trevor-lawrence" tabindex="0"><div class="headshot inline-block relative TableHeadshot roster-headshot headshot--sm athlete silo"><figure class="Image aspect-ratio--parent"><div class="RatioFrame aspect-ratio--1x1"></div><div class="Image__Wrapper aspect-ratio--child"><img alt="https://a.espncdn.com/i/headshots/college-football/players/full/4360310.png" class="" data-mptype="image" src="..." title="Trevor Lawrence"/></div></figure></div></a></div></td><td class="Table__TD"><div class="inline" style="min-width:140px"><a class="AnchorLink" href="http://www.espn.com/college-football/player/_/id/4360310/trevor-lawrence" tabindex="0">Trevor Lawrence</a><span class="pl2 n1 ...

# %%
t = soup.find(class_="Table__Title", string="Offense").find_next("table")

# %% [markdown]
# ### Extract the table's column names

# %%
t.thead
type(t.thead)
# Out:
# bs4.element.Tag

# %%
t.thead
# Out:
# <thead class="Table__header-group Table__THEAD"><tr class="Table__sub-header Table__TR Table__even"><th class="Table__TD--headshot Table__TH" title=""><span class="fw-medium w-100 dib Table__TD--headshot" style="min-width:40px" title=""></span></th><th class="Table__TH" title=""><span class="fw-medium w-100 dib" style="min-width:140px" title="">Name</span></th><th class="Table__TH" title=""><span class="fw-medium w-100 dib underline" title=""><a class="AnchorLink clr-gray-04" href="/college-football/team/roster/_/id/228/sort/position/dir/asc/clemson-tigers" tabindex="0">POS</a></span></th><th class="Table__TH" title=""><span class="fw-medium w-100 dib underline" style="min-width:50px" title=""><a class="AnchorLink clr-gray-04" href="/college-football/team/roster/_/id/228/sort/height/dir/asc/clemson-tigers" tabindex="0">HT</a></span></th><th class="Table__TH" title=""><span class="fw-medium w-100 dib underline" style="min-width:70px" title=""><a class="AnchorLink clr-gray-04" href="/college-football/team/roster/_/id/228/sort/weight/dir/asc/clemson-tigers" tabindex="0">WT</a></span></th><th class="Table__TH" title=""><span class="fw-medium w-100 dib underline" title=""><a class="AnchorLink clr-gray-04" href="/college-football/team/roster/_/id/228/sort/experience/dir/asc/clemson-tigers" tabindex="0">Class</a></span></th><th class="Table__TH" title=""><span class="fw-medium w-100 dib" title="">Birthplace</span></th></tr></thead>

# %%
for c in t.children:
    print(c.name)
# Out:
# colgroup
# thead
# tbody

# %% [markdown]
# ### One way to find the column names

# %%
for c in t.thead.tr.children:
    print(c.text)
# Out:
# Name
# POS
# HT
# WT
# Class
# Birthplace

# %% [markdown]
# ### Another way to find the column names

# %%
for i, col in enumerate(t.find_all('th')):
    print("{}\t{}".format(i, col.get_text()))
# Out:
# 0
# 1	Name
# 2	POS
# 3	HT
# 4	WT
# 5	Class
# 6	Birthplace

# %% [markdown]
# ### Save the names to a list
# + Use for loops
# + Use list comprehension

# %%
# Use for loops to save the column names into a list
headers = []
for c in t.find_all('th'):
    headers.append(c.get_text())
headers
# Out:
# ['', 'Name', 'POS', 'HT', 'WT', 'Class', 'Birthplace']

# %%
# Use list comprehension 
headers = [c.get_text() for c in t.find_all('th')]
headers
# Out:
# ['', 'Name', 'POS', 'HT', 'WT', 'Class', 'Birthplace']

# %% [markdown]
# ### Extract the players' data

# %%
# Find the html structure for the player data
for c in t.tbody.children:
    print(c.name, c.attrs)
# Out:
# tr {'class': ['Table__TR', 'Table__TR--lg', 'Table__even'], 'data-idx': '0'}
# tr {'class': ['Table__TR', 'Table__TR--lg', 'Table__even'], 'data-idx': '1'}
# tr {'class': ['Table__TR', 'Table__TR--lg', 'Table__even'], 'data-idx': '2'}
# tr {'class': ['Table__TR', 'Table__TR--lg', 'Table__even'], 'data-idx': '3'}
# tr {'class': ['Table__TR', 'Table__TR--lg', 'Table__even'], 'data-idx': '4'}
# tr {'class': ['Table__TR', 'Table__TR--lg', 'Table__even'], 'data-idx': '5'}
# tr {'class': ['Table__TR', 'Table__TR--lg', 'Table__even'], 'data-idx': '6'}
# tr {'class': ['Table__TR', 'Table__TR--lg', 'Table__even'], 'data-idx': '7'}
# tr {'class': ['Table__TR', 'Table__TR--lg', 'Table__even'], 'data-idx': '8'}
# tr {'class': ['Table__TR', 'Table__TR--lg', 'Table__even'], 'data-idx': '9'}
# tr {'class': ['Table__TR', 'Table__TR--lg', 'Table__even'], 'data-idx': '10'}
# tr {'class': ['Table__TR', 'Table__TR--lg', 'Table__even'], 'data-idx': '11'}
# tr {'class': ['Table__TR', 'Table__TR--lg', 'Table__even'], 'data-idx': '12'}
# tr {'class': ['Table__TR', 'Table__TR--lg', 'Table__even'], 'data-idx': '13'}
# tr {'class': ['Table__TR', 'Table__TR--lg', 'Table__even'], 'data-idx': '14'}
# tr {'class': ['Table__TR', 'Table__TR--lg', 'Table__even'], 'data-idx': '15'}
# tr {'class': ['Table__TR', 'Table__TR--lg', 'Table__even'], 'data-idx': '16'}
# tr {'class': ['Table__TR', 'Table__TR--lg', 'Table__even'], 'data-idx': '17'}
# tr {'class': ['Table__TR', 'Table__TR--lg', 'Table__even'], 'data-idx': '18'}
# tr {'class': ['Table__TR', 'Table__TR--lg', 'Table__even'], 'data-idx': '19'}
# tr {'class': ['Table__TR', 'Table__TR--lg', 'Table__even'], 'data-idx': '20'}
# tr {'class': ['Table__TR', 'Table__TR--lg', 'Table__even'], 'data-idx': '21'}
# tr {'class': ['Table__TR', 'Table__TR--lg', 'Table__even'], 'data-idx': '22'}
# tr {'class': ['Table__TR', 'Table__TR--lg', 'Table__even'], 'data-idx': '23'}
# tr {'class': ['Table__TR', 'Table__TR--lg', 'Table__even'], 'data-idx': '24'}
# tr {'class': ['Table__TR', 'Table__TR--lg', 'Table__even'], 'data-idx': '25'}
# tr {'class': ['Table__TR', 'Table__TR--lg', 'Table__even'], 'data-idx': '26'}
# tr {'class': ['Table__TR', 'Table__TR--lg', 'Table__even'], 'data-idx': '27'}
# tr {'class': ['Table__TR', 'Table__TR--lg', 'Table__even'], 'data-idx': '28'}
# tr {'class': ['Table__TR', 'Table__TR--lg', 'Table__even'], 'data-idx': '29'}
# tr {'class': ['Table__TR', 'Table__TR--lg', 'Table__even'], 'data-idx': '30'}
# tr {'class': ['Table__TR', 'Table__TR--lg', 'Table__even'], 'data-idx': '31'}
# tr {'class': ['Table__TR', 'Table__TR--lg', 'Table__even'], 'data-idx': '32'}
# tr {'class': ['Table__TR', 'Table__TR--lg', 'Table__even'], 'data-idx': '33'}
# tr {'class': ['Table__TR', 'Table__TR--lg', 'Table__even'], 'data-idx': '34'}
# tr {'class': ['Table__TR', 'Table__TR--lg', 'Table__even'], 'data-idx': '35'}
# tr {'class': ['Table__TR', 'Table__TR--lg', 'Table__even'], 'data-idx': '36'}
# tr {'class': ['Table__TR', 'Table__TR--lg', 'Table__even'], 'data-idx': '37'}
# tr {'class': ['Table__TR', 'Table__TR--lg', 'Table__even'], 'data-idx': '38'}
# tr {'class': ['Table__TR', 'Table__TR--lg', 'Table__even'], 'data-idx': '39'}
# tr {'class': ['Table__TR', 'Table__TR--lg', 'Table__even'], 'data-idx': '40'}
# tr {'class': ['Table__TR', 'Table__TR--lg', 'Table__even'], 'data-idx': '41'}
# tr {'class': ['Table__TR', 'Table__TR--lg', 'Table__even'], 'data-idx': '42'}
# tr {'class': ['Table__TR', 'Table__TR--lg', 'Table__even'], 'data-idx': '43'}
# tr {'class': ['Table__TR', 'Table__TR--lg', 'Table__even'], 'data-idx': '44'}
# tr {'class': ['Table__TR', 'Table__TR--lg', 'Table__even'], 'data-idx': '45'}
# tr {'class': ['Table__TR', 'Table__TR--lg', 'Table__even'], 'data-idx': '46'}
# tr {'class': ['Table__TR', 'Table__TR--lg', 'Table__even'], 'data-idx': '47'}
# tr {'class': ['Table__TR', 'Table__TR--lg', 'Table__even'], 'data-idx': '48'}
# tr {'class': ['Table__TR', 'Table__TR--lg', 'Table__even'], 'data-idx': '49'}
# tr {'class': ['Table__TR', 'Table__TR--lg', 'Table__even'], 'data-idx': '50'}
# tr {'class': ['Table__TR', 'Table__TR--lg', 'Table__even'], 'data-idx': '51'}
# tr {'class': ['Table__TR', 'Table__TR--lg', 'Table__even'], 'data-idx': '52'}
# tr {'class': ['Table__TR', 'Table__TR--lg', 'Table__even'], 'data-idx': '53'}
# tr {'class': ['Table__TR', 'Table__TR--lg', 'Table__even'], 'data-idx': '54'}
# tr {'class': ['Table__TR', 'Table__TR--lg', 'Table__even'], 'data-idx': '55'}
# tr {'class': ['Table__TR', 'Table__TR--lg', 'Table__even'], 'data-idx': '56'}

# %%
def is_player_row(tag):
    if tag.name == 'tr' and tag.has_attr('data-idx'):
        return True
    return False
    
for i, c in enumerate(t.tbody.find_all(is_player_row)):
    tds = c.find_all('td')
    cols = []
    for td in tds:
        cols.append(td.get_text())
    print("{}\t{}".format(i, cols))
# Out:
# 0	['', 'Hunter Helms18', 'QB', '6\' 2"', '210 lbs', 'FR', 'West Columbia, SC']
# 1	['', 'Trevor Lawrence16', 'QB', '6\' 6"', '220 lbs', 'JR', 'Cartersville, GA']
# 2	['', 'Patrick McClure15', 'QB', '6\' 1"', '200 lbs', 'JR', 'Irmo, SC']
# 3	['', 'Taisun Phommachanh7', 'QB', '6\' 3"', '220 lbs', 'FR', 'Bridgeport, CT']
# 4	['', 'D.J. Uiagalelei5', 'QB', '6\' 5"', '245 lbs', 'FR', 'Bellflower, CA']
# 5	['', 'Demarkcus Bowman1', 'RB', '5\' 10"', '190 lbs', 'FR', 'Lakeland, FL']
# 6	['', 'Lyn-J Dixon23', 'RB', '5\' 10"', '190 lbs', 'JR', 'Butler, GA']
# 7	['', 'Michel Dukes19', 'RB', '5\' 10"', '195 lbs', 'SO', 'Charleston, SC']
# 8	['', 'Travis Etienne9', 'RB', '5\' 10"', '210 lbs', 'SR', 'Jennings, LA']
# 9	['', 'Ty Lucas33', 'RB', '5\' 7"', '205 lbs', 'SO', 'Columbus, GA']
# 10	['', 'Sylvester Mayers32', 'RB', '5\' 6"', '150 lbs', 'JR', 'Richmond, VA']
# 11	['', 'Chez Mellusi27', 'RB', '5\' 11"', '200 lbs', 'SO', 'Naples, FL']
# 12	['', 'Kobe Pace14', 'RB', '5\' 11"', '215 lbs', 'FR', 'Cedartown, GA']
# 13	['', 'Darien Rencher21', 'RB', '5\' 8"', '195 lbs', 'SR', 'Anderson, SC']
# 14	['', 'Ajou Ajou11', 'WR', '6\' 4"', '220 lbs', 'FR', 'Brooks, AB']
# 15	['', 'Will Brown82', 'WR', '5\' 8"', '180 lbs', 'JR', 'Boiling Springs, SC']
# 16	['', 'Hampton Earle83', 'WR', '5\' 10"', '180 lbs', 'FR', 'Clemson, SC']
# 17	['', 'Hamp Greene87', 'WR', '5\' 9"', '165 lbs', 'FR', 'Birmingham, AL']
# 18	['', 'Tye Herbstreit86', 'WR', '5\' 10"', '165 lbs', 'FR', 'Nashville, TN']
# 19	['', 'Josh Jackson45', 'WR', '6\' 1"', '190 lbs', 'SR', 'Greenville, SC']
# 20	['', 'Frank Ladson Jr.2', 'WR', '6\' 3"', '195 lbs', 'SO', 'Miami, FL']
# 21	['', 'Max May89', 'WR', '6\' 1"', '190 lbs', 'SO', 'Clemson, SC']
# 22	['', 'Joseph Ngata10', 'WR', '6\' 3"', '215 lbs', 'SO', 'Folsom, CA']
# 23	['', 'Cornell Powell17', 'WR', '6\' 0"', '210 lbs', 'SR', 'Greenville, NC']
# 24	['', 'Amari Rodgers3', 'WR', '5\' 10"', '210 lbs', 'SR', 'Knoxville, TN']
# 25	['', 'Justyn Ross8', 'WR', '6\' 4"', '205 lbs', 'JR', 'Phenix City, AL']
# 26	['', 'Brannon Spector13', 'WR', '6\' 1"', '195 lbs', 'FR', 'Calhoun, GA']
# 27	['', 'Drew Swinney81', 'WR', '5\' 8"', '180 lbs', 'SO', 'Clemson, SC']
# 28	['', 'Will Swinney22', 'WR', '5\' 8"', '185 lbs', 'SR', 'Clemson, SC']
# 29	['', 'E.J. Williams6', 'WR', '6\' 4"', '190 lbs', 'FR', 'Phenix City, AL']
# 30	['', 'Davis Allen84', 'TE', '6\' 6"', '240 lbs', 'SO', 'Calhoun, GA']
# 31	['', 'Will Blackston43', 'TE', '6\' 1"', '235 lbs', 'FR', 'Honea Path, SC']
# 32	['', 'J.C. Chalk25', 'TE', '6\' 3"', '255 lbs', 'SR', 'Argyle, TX']
# 33	['', 'Sage Ennis87', 'TE', '6\' 4"', '230 lbs', 'FR', 'Graceville, FL']
# 34	['', 'Braden Galloway88', 'TE', '6\' 4"', '240 lbs', 'JR', 'Anderson, SC']
# 35	['', 'Jaelyn Lay85', 'TE', '6\' 6"', '270 lbs', 'FR', 'Atlanta, GA']
# 36	['', 'Luke Price80', 'TE', '6\' 2"', '230 lbs', 'JR', 'Dillon, SC']
# 37	['', 'Matt Bockhorst65', 'G', '6\' 4"', '310 lbs', 'JR', 'Cincinnati, OH']
# 38	['', 'Kaleb Boateng50', 'OL', '6\' 3"', '300 lbs', 'FR', 'Fort Lauderdale, FL']
# 39	['', 'Will Boggs68', 'OL', '6\' 4"', '285 lbs', 'FR', 'York, SC']
# 40	['', 'Mac Cranford60', 'OL', '6\' 0"', '280 lbs', 'FR', 'Hartsville, SC']
# 41	['', 'Jacob Edwards69', 'OL', '6\' 2"', '295 lbs', 'JR', 'Vestavia Hills, AL']
# 42	['', 'Trent Howard75', 'OL', '6\' 4"', '285 lbs', 'FR', 'Birmingham, AL']
# 43	['', 'Mitchell Mayes77', 'OL', '6\' 4"', '315 lbs', 'FR', 'Raleigh, NC']
# 44	['', 'Zac McIntosh63', 'OL', '5\' 11"', '295 lbs', 'JR', 'Belton, SC']
# 45	['', 'Walker Parks64', 'OL', '6\' 5"', '275 lbs', 'FR', 'Lexington, KY']
# 46	['', 'Will Putnam56', 'OL', '6\' 4"', '295 lbs', 'SO', 'Tampa, FL']
# 47	['', 'Hunter Rayburn55', 'OL', '6\' 4"', '315 lbs', 'FR', 'Pensacola, FL']
# 48	['', 'Cade Stewart62', 'OL', '6\' 3"', '305 lbs', 'SR', 'Six Mile, SC']
# 49	['', 'Paul Tchio57', 'OL', '6\' 5"', '300 lbs', 'FR', 'Milton, GA']
# 50	['', 'Mason Trotter54', 'OL', '6\' 2"', '270 lbs', 'FR', 'Roebuck, SC']
# 51	['', 'Bryn Tucker73', 'OL', '6\' 5"', '290 lbs', 'FR', 'Knoxville, TN']
# 52	['', 'Blake Vinson72', 'OL', '6\' 4"', '300 lbs', 'SO', 'Ocala, FL']
# 53	['', 'John Williams76', 'OL', '6\' 5"', '280 lbs', 'FR', 'Canton, GA']
# 54	['', 'Jackson Carman79', 'OT', '6\' 5"', '345 lbs', 'JR', 'Fairfield, OH']
# 55	['', 'Will Edwards67', 'OT', '6\' 5"', '255 lbs', 'SO', 'Greenville, SC']
# 56	['', 'Jordan McFadden71', 'OT', '6\' 2"', '295 lbs', 'SO', 'Spartanburg, SC']

# %% [markdown]
# ## Save the Extracted Data
#
# We can substitute the `print` function with file's `write` method in the above code snippet. But here, we first save the data into a list and then write the list to files.

# %%
players = []
for c in t.tbody.find_all(is_player_row):
    tds = c.find_all('td')
    cols = []
    for td in tds:
        cols.append(td.get_text())
    players.append(cols)

# %%
players[0:2]
# Out:
# [['', 'Hunter Helms18', 'QB', '6\' 2"', '210 lbs', 'FR', 'West Columbia, SC'],
#  ['',
#   'Trevor Lawrence16',
#   'QB',
#   '6\' 6"',
#   '220 lbs',
#   'JR',
#   'Cartersville, GA']]

# %%
# Write the results to a csv file
def write_csv(headers, rows, path):
    with open(path, "w") as f:
        f.write(','.join(headers[1:]))
        f.write('\n')
        for row in rows:
            f.write(','.join(row[1:]))
            f.write('\n')
write_csv(headers, players, "clemson_tigers_roster.csv")

# %%
# !head -n 4 clemson_tigers_roster.csv
# Out:
# Name,POS,HT,WT,Class,Birthplace
# Hunter Helms18,QB,6' 2",210 lbs,FR,West Columbia, SC
# Trevor Lawrence16,QB,6' 6",220 lbs,JR,Cartersville, GA
# Patrick McClure15,QB,6' 1",200 lbs,JR,Irmo, SC

# %% [markdown]
# ### Data format
#
# You may notice the comma in the birth place, which may cause confusions. You may have multiple choices:
# + Replace the ',' with a "-".
# + Split the birthplace into two columns: birth_city and birth_state
#
# Below, we use the split approach.

# %%
def write_csv(headers, rows, path):
    new_headers = ['Name', 'Position', 'Height', 'Weight', 'Class', 'Birth_City', 'Birth_State']
    with open(path, "w") as f:
        f.write(','.join(new_headers))
        f.write('\n')
        for row in rows:
            city, state = row[-1].split(',')
            new_row = [c.replace(',', ' ') for c in row[:6]]
            new_row.append(city.strip())
            new_row.append(state.strip())
            # print(new_row)
            f.write(','.join(new_row[1:]))
            f.write('\n')
write_csv(headers, players, "clemson_tigers_roster.csv")

# %%
# !head -n 4 clemson_tigers_roster.csv
# Out:
# Name,Position,Height,Weight,Class,Birth_City,Birth_State
# Hunter Helms18,QB,6' 2",210 lbs,FR,West Columbia,SC
# Trevor Lawrence16,QB,6' 6",220 lbs,JR,Cartersville,GA
# Patrick McClure15,QB,6' 1",200 lbs,JR,Irmo,SC

# %% [markdown]
# You may also find it might be more convinient to represent the weight and height with numbers insteads of strings.
# We can change the corresponding header names to preserve the unit information.

# %%
import re
HEIGHT_RE = re.compile(r"(\d+)\'\s+(\d+)\"")
WEIGHT_RE = re.compile(r"(\d+)\s+lbs")


def parse_height(ht):
    m = HEIGHT_RE.match(ht)
    if m:
        return float(m.group(1)) + float(m.group(2))/12
    return -1

def parse_weight(wt):
    m = WEIGHT_RE.match(wt)
    if m:
        return float(m.group(1))
    return -1


def write_csv(headers, rows, path):
    new_headers = ['Name', 'Position', 'Height (ft)', 'Weight (lbs)', 'Class', 'Birth_City', 'Birth_State']
    with open(path, "w") as f:
        f.write(','.join(new_headers))
        f.write('\n')
        for row in rows:
            city, state = row[-1].split(',')
            new_row = [c.replace(',', ' ') for c in row[:6]]
            new_row.append(city.strip())
            new_row.append(state.strip())
            new_row[3] = "{:.1f}".format(parse_height(new_row[3]))
            new_row[4] = "{:.0f}".format(parse_weight(new_row[4]))
            # print(new_row)
            f.write(','.join(new_row[1:]))
            f.write('\n')
write_csv(headers, players, "clemson_tigers_roster.csv")

# %% [markdown]
# # Perform Simple Data Analysis Using pandas

# %% [markdown]
# ## Read the Data into a pandas DataFrame

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
roster = pd.read_csv("clemson_tigers_roster.csv")

# %% [markdown]
# ## Get Some Basic Descriptive Statistics

# %%
roster.head(10)
# Out:
#                   Name Position  Height (ft)  Weight (lbs) Class  \
# 0       Hunter Helms18       QB          6.2           210    FR
# 1    Trevor Lawrence16       QB          6.5           220    JR
# 2    Patrick McClure15       QB          6.1           200    JR
# 3  Taisun Phommachanh7       QB          6.2           220    FR
# 4     D.J. Uiagalelei5       QB          6.4           245    FR
# 5    Demarkcus Bowman1       RB          5.8           190    FR
# 6        Lyn-J Dixon23       RB          5.8           190    JR
# 7       Michel Dukes19       RB          5.8           195    SO
# 8      Travis Etienne9       RB          5.8           210    SR
# 9           Ty Lucas33       RB          5.6           205    SO
#
#       Birth_City Birth_State
# 0  West Columbia          SC
# 1   Cartersville          GA
# 2           Irmo          SC
# 3     Bridgeport          CT
# 4     Bellflower          CA
# 5       Lakeland          FL
# 6         Butler          GA
# 7     Charleston          SC
# 8       Jennings          LA
# 9       Columbus          GA

# %%
roster.describe()
# Out:
#        Height (ft)  Weight (lbs)
# count    57.000000     57.000000
# mean      6.115789    237.017544
# std       0.260350     48.686861
# min       5.500000    150.000000
# 25%       5.900000    195.000000
# 50%       6.200000    220.000000
# 75%       6.300000    285.000000
# max       6.500000    345.000000

# %% [markdown]
# ## Plot the Data

# %%
sns.set_style("whitegrid")
g = sns.scatterplot(x=roster["Position"], y=roster["Weight (lbs)"])
g.set_title("Position vs Weight")
g.set_xlabel("Position")
g.set_ylabel("Weight")
# Out:
# Text(0, 0.5, 'Weight')

# %%
roster['Birth_State'] = roster['Birth_State'].astype('category')
g = roster['Birth_State'].value_counts().plot.bar()
